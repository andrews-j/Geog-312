# %% [markdown]
# ## **Section 5:** Calculate Stats

# %%
# Import a few packages
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import os
pd.options.display.max_rows = 300

# %%
print(os.getcwd())
os.chdir('G:/My Drive/Clark')
print(os.getcwd())
# Out:
# G:\My Drive\Clark\GIS Tutorials\GeoPy\1.Geopandas
# G:\My Drive\Clark

# %% [markdown]
# ### Read in countries gdf from parquet file

# %%
# Load the Parquet file
countries_gdf = gpd.read_parquet("GIS Tutorials/GeoPy/1.Geopandas/activity_files/checkpoint4/countries.parquet")
countries_gdf.head()
# Out:
#                  COUNTRY   ISO      COUNTRYAFF  Population  \
# 0            Afghanistan    AF     Afghanistan    34262840
# 1  Akrotiri and Dhekelia  None  United Kingdom       18195
# 2                Albania    AL         Albania     2402113
# 3                Algeria    DZ         Algeria    46700000
# 4         American Samoa    AS   United States       49710
#
#                                 formalName  \
# 0           Islamic Emirate of Afghanistan
# 1                                     None
# 2                      Republic of Albania
# 3  People's Democratic Republic of Algeria
# 4                                     None
#
#                                             geometry  \
# 0  POLYGON ((74.88986 37.23409, 74.88962 37.23314...
# 1  MULTIPOLYGON (((33.90121 35.09612, 33.90185 35...
# 2  MULTIPOLYGON (((20.0789 42.5558, 20.07939 42.5...
# 3  MULTIPOLYGON (((8.64188 36.94206, 8.64196 36.9...
# 4  MULTIPOLYGON (((-168.17253 -14.55294, -168.173...
#
#                       centroid  centOut              Capital     capPop  \
# 0    POINT (65.98786 33.75477)      0.0                Kabul  4011770.0
# 1    POINT (33.36206 34.83019)      1.0  Episkopi Cantonment     1500.0
# 2    POINT (20.06737 41.12698)      0.0               Tirana   475577.0
# 3     POINT (2.68012 27.89881)      0.0              Algiers  2693542.0
# 4  POINT (-170.3959 -14.21789)      1.0            Pago Pago    48526.0
#
#                        capLoc
# 0     POINT (69.1725 34.5289)
# 1     POINT (32.6242 34.6769)
# 2     POINT (19.8189 41.3275)
# 3       POINT (3.042 36.7525)
# 4  POINT (-170.7025 -14.2781)

# %%
# Map with capitals sized by capPop
import folium
from folium import Popup, CircleMarker
from folium import Circle
from shapely.geometry import Point

# Center of the map (choose appropriate coordinates for your map)
map_center = [20, 0]  # Adjust as needed
m = folium.Map(location=map_center, zoom_start=2)

# Loop through each row in the DataFrame to add markers
for idx, row in countries_gdf.iterrows():
    if isinstance(row['capLoc'], Point):  # Ensure geometry is a Point
        # Extract latitude and longitude from the geometry column
        lat, lon = row['capLoc'].y, row['capLoc'].x
        
        # Set marker size by population with a minimum size threshold
        population = row['capPop']
        radius = max(4, min(population / 100000, 30))  # Adjust scaling as needed
        
        # Create the popup text
        tooltip_text = f"""
            <b>Country:</b> {row['COUNTRY']}<br>
            <b>Capital:</b> {row['Capital']}<br>
            <b>Population:</b> {int(population):,}
        """
        
        # Add a circle marker with a tooltip to the map
        CircleMarker(
            location=(lat, lon),
            radius=radius,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6,
            tooltip=tooltip_text
        ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a327b30730172cff7145e1fdbf804da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a327b30730172cff7145e1fdbf804da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a327b30730172cff7145e1fdbf804da = L.map(
#                 &quot;map_9a327b30730172cff7145e1fdbf804da&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc2125a9ab0e0778e5b1e701556a16b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fc2125a9ab0e0778e5b1e701556a16b9.addTo(map_9a327b30730172cff7145e1fdbf804da);
#
#
#             var circle_marker_73d8e06d552ca01267ba8fbddd410d44 = L.circleMarker(
#                 [34.5289, 69.1725],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a327b30730172cff7145e1fdbf804da);
#
#
#             circle_marker_73d8e06d552ca01267ba8fbddd410d44.bindTooltip(
#                 `&lt;div&gt;
#
#             &lt;b&gt;Country:&lt;/b&gt; Afghanistan&lt;br&gt;
#             &lt;b&gt;Capital:&lt;/b&gt; Kabul&lt;br&gt;
#             &lt;b&gt;Population:&lt;/b&gt; 4,011,770
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_27038fe81f435ec0f40d587f60372e6a = L.circleMarker(
#                 [34.6769, 32.6242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a327b30730172cff7145e1fdbf804da);
#
#
#             circle_marker_27038fe81f435ec0f40d587f60372e6a.bindTooltip(
#                 `&lt;div&gt;
#
#             &lt;b&gt;Country:&lt;/b&gt; Akrotiri and Dhekelia&lt;br&gt;
#             &lt;b&gt;Capital:&lt;/b&gt; Episkopi Cantonment&lt;br&gt;
#             &lt;b&gt;Population:&lt;/b&gt; 1,500
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_9cadb800cd1a9ffe2cfcba78ff8973c3 = L.circleMarker(
#                 [41.3275, 19.8189],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.75577, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a327b30730172cff7145e1fdbf804da);
#
#
#             circle_marker_9cadb800cd1a9ffe2cfcba78ff8973c3.bindTooltip(
#                 `&lt;div&gt;
#
#             &lt;b&gt;Country:&lt;/b&gt; Albania&lt;br&gt;
#             &lt;b&gt;Capital:&lt;/b&gt; Tirana&lt;br&gt;
#             &lt;b&gt;Population:&lt;/b&gt; 475,577
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_8c15c03d49bc7058babac36aa952e111 = L.circleMarker(
#                 [36.7525, 3.042],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 26.93542, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a327b30730172cff7145e1fdbf804da);
#
#
#             circle_marker_8c15c03d49bc7058babac36aa952e111.bindTooltip(
#                 `&lt;div&gt;
#
#             &lt;b&gt;Country:&lt;/b&gt; Algeria&lt;br&gt;
#             &lt;b&gt;Capital:&lt;/b&gt; Algiers&lt;br&gt;
#             &lt;b&gt;Population:&l

# %%
# Map with capitals sized by capPop
import folium
from folium import Popup, CircleMarker
from folium import Circle
from shapely.geometry import Point

# Center of the map (choose appropriate coordinates for your map)
map_center = [20, 0]  # Adjust as needed
m = folium.Map(location=map_center, zoom_start=2)

# Loop through each row in the DataFrame to add markers
for idx, row in countries_gdf.iterrows():
    if isinstance(row['capLoc'], Point):  # Ensure geometry is a Point
        # Extract latitude and longitude from the geometry column
        lat, lon = row['capLoc'].y, row['capLoc'].x
        
        # Create the popup text
        tooltip_text = f"""
            <b>Country:</b> {row['COUNTRY']}<br>
            <b>Capital:</b> {row['Capital']}<br>
            <b>Population:</b> {int(population):,}
        """
        
        # Add a circle marker with a tooltip to the map
        CircleMarker(
            location=(lat, lon),
            radius=3,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6,
            tooltip=tooltip_text
        ).add_to(m)

# Loop through each row in the DataFrame to add markers
for idx, row in countries_gdf.iterrows():
    if isinstance(row['centroid'], Point):  # Ensure geometry is a Point
        # Extract latitude and longitude from the geometry column
        lat, lon = row['centroid'].y, row['centroid'].x
        
        # Create the popup text
        tooltip_text = f"""
            {row['COUNTRY']} centroid<br>
        """
        
        # Add a circle marker with a tooltip to the map
        CircleMarker(
            location=(lat, lon),
            radius=3,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.6,
            tooltip=tooltip_text
        ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5848ccf7fbe6bed2c2350f154105becb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5848ccf7fbe6bed2c2350f154105becb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5848ccf7fbe6bed2c2350f154105becb = L.map(
#                 &quot;map_5848ccf7fbe6bed2c2350f154105becb&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcde983ff0fda7ad17469130971e44d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fcde983ff0fda7ad17469130971e44d3.addTo(map_5848ccf7fbe6bed2c2350f154105becb);
#
#
#             var circle_marker_7d4f0ff283e14249caf73001f890be67 = L.circleMarker(
#                 [34.5289, 69.1725],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5848ccf7fbe6bed2c2350f154105becb);
#
#
#             circle_marker_7d4f0ff283e14249caf73001f890be67.bindTooltip(
#                 `&lt;div&gt;
#
#             &lt;b&gt;Country:&lt;/b&gt; Afghanistan&lt;br&gt;
#             &lt;b&gt;Capital:&lt;/b&gt; Kabul&lt;br&gt;
#             &lt;b&gt;Population:&lt;/b&gt; 1,515,016
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c0f4f2f9cf994f19a64113156ed27505 = L.circleMarker(
#                 [34.6769, 32.6242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5848ccf7fbe6bed2c2350f154105becb);
#
#
#             circle_marker_c0f4f2f9cf994f19a64113156ed27505.bindTooltip(
#                 `&lt;div&gt;
#
#             &lt;b&gt;Country:&lt;/b&gt; Akrotiri and Dhekelia&lt;br&gt;
#             &lt;b&gt;Capital:&lt;/b&gt; Episkopi Cantonment&lt;br&gt;
#             &lt;b&gt;Population:&lt;/b&gt; 1,515,016
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_48100c17cc73f739a7aa38c46be83bcd = L.circleMarker(
#                 [41.3275, 19.8189],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5848ccf7fbe6bed2c2350f154105becb);
#
#
#             circle_marker_48100c17cc73f739a7aa38c46be83bcd.bindTooltip(
#                 `&lt;div&gt;
#
#             &lt;b&gt;Country:&lt;/b&gt; Albania&lt;br&gt;
#             &lt;b&gt;Capital:&lt;/b&gt; Tirana&lt;br&gt;
#             &lt;b&gt;Population:&lt;/b&gt; 1,515,016
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f681f03c88727f96c2db18058070f2a3 = L.circleMarker(
#                 [36.7525, 3.042],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5848ccf7fbe6bed2c2350f154105becb);
#
#
#             circle_marker_f681f03c88727f96c2db18058070f2a3.bindTooltip(
#                 `&lt;div&gt;
#
#             &lt;b&gt;Country:&lt;/b&gt; Algeria&lt;br&gt;
#             &lt;b&gt;Capital:&lt;/b&gt; Algiers&lt;br&gt;
#             &lt;b&gt;Population:&lt;/b&gt;

# %%
# For more distance calculations we will reconvert to equal area projection (EPSG:6933)
def reproject_geom_centroid_capLoc(gdf, target_crs):
    """
    Reprojects the given GeoDataFrame to the target CRS, calculates the centroid coordinates
    in the target CRS, and adds the centroid coordinates as new columns to the reprojected GDF.

    Parameters:
    gdf (GeoDataFrame): The input GeoDataFrame with geometries to reproject.
    target_crs (str or int): The target CRS, either as an EPSG code or a PROJ string.

    Returns:
    GeoDataFrame: The reprojected GeoDataFrame with centroid coordinates as new columns.
    """
    # Reproject the GeoDataFrame to the target CRS
    gdf_reproj = gdf
    gdf_reproj = gdf_reproj.to_crs(epsg=target_crs)
    gdf_reproj['centroid'] = gdf_reproj['centroid'].to_crs(epsg=target_crs)
    gdf_reproj['capLoc'] = gdf_reproj['capLoc'].to_crs(epsg=target_crs)

    # Return the reprojected GeoDataFrame with centroid coordinates
    return gdf_reproj

# %%
# run the reprojections
countries6933 = reproject_geom_centroid_capLoc(countries_gdf, 6933)
# and check everything is in meters
countries6933.head()
# Out:
#                  COUNTRY   ISO      COUNTRYAFF  Population  \
# 0            Afghanistan    AF     Afghanistan    34262840
# 1  Akrotiri and Dhekelia  None  United Kingdom       18195
# 2                Albania    AL         Albania     2402113
# 3                Algeria    DZ         Algeria    46700000
# 4         American Samoa    AS   United States       49710
#
#                                 formalName  \
# 0           Islamic Emirate of Afghanistan
# 1                                     None
# 2                      Republic of Albania
# 3  People's Democratic Republic of Algeria
# 4                                     None
#
#                                             geometry  \
# 0  POLYGON ((7225844.213 4429969.157, 7225820.477...
# 1  MULTIPOLYGON (((3271001.456 4208757.217, 32710...
# 2  MULTIPOLYGON (((1937337.89 4953531.349, 193738...
# 3  MULTIPOLYGON (((833823.241 4400105.217, 833831...
# 4  MULTIPOLYGON (((-16226341.969 -1837186.441, -1...
#
#                             centroid  centOut              Capital     capPop  \
# 0    POINT (6366923.369 4067003.427)      0.0                Kabul  4011770.0
# 1    POINT (3218981.275 4180831.547)      1.0  Episkopi Cantonment     1500.0
# 2    POINT (1936226.181 4816925.086)      0.0               Tirana   475577.0
# 3     POINT (258594.776 3423503.593)      0.0              Algiers  2693542.0
# 4  POINT (-16440866.53 -1795748.571)      1.0            Pago Pago    48526.0
#
#                                capLoc
# 0     POINT (6674197.221 4149086.179)
# 1     POINT (3147787.704 4164694.464)
# 2      POINT (1912251.94 4836277.237)
# 3      POINT (293511.265 4380659.647)
# 4  POINT (-16470449.255 -1803199.427)

# %%
# Assuming countries_w_caps has the centroids and capital locations
# Create a DataFrame to hold the results
closer_centroids = []

# Loop through each country
for idx, country in countries_w_caps.iterrows():
    country_centroid = country['centroid']
    country_cap_loc = country['capLoc']
    
    # Calculate the distance to the centroid of each country
    distances = countries_w_caps['capLoc'].distance(country_centroid)

    # Find the closest capital city (not the country's own capital)
    closest_index = distances[distances.index != idx].idxmin()
    closest_distance = distances[closest_index]

    # Compare distances
    if closest_distance < country_cap_loc.distance(country_centroid):
        closer_centroids.append({
            'country': country['COUNTRY'],
            'closest_country': countries_w_caps.loc[closest_index]['COUNTRY'],
            'distance_to_closest': closest_distance,
            'own_distance': country_cap_loc.distance(country_centroid)
        })

# Create a DataFrame with the results
closer_centroids_df = gpd.GeoDataFrame(closer_centroids)

# Display the results
print(closer_centroids_df)
# Out:
# -----------------------------------------------------
# AttributeError      Traceback (most recent call last)
# Cell In[124], line 18
#      15     closest_distance = distances[closest_index]
#      17     # Compare distances
# ---> 18     if closest_distance < country_cap_loc.distance(country_centroid):
#      19         closer_centroids.append({
#      20             'country': country['COUNTRY'],
#      21             'closest_country': countries_w_caps.loc[closest_index]['COUNTRY'],
#      22             'distance_to_closest': closest_distance,
#      23             'own_distance': country_cap_loc.distance(country_centroid)
#      24         })
#      26 # Create a DataFrame with the results
#
# AttributeError: 'NoneType' object has no attribute 'distance'

# %% [markdown]
# ## Summary
#
# This lecture provided an introduction to working with geospatial data using GeoPandas. We covered basic concepts such as reading/writing geospatial data, performing spatial operations (e.g., buffering, intersections), and visualizing geospatial data using maps. GeoPandas, built on Pandas and Shapely, enables efficient and intuitive geospatial analysis in Python.

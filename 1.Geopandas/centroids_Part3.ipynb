# %% [markdown]
# ## **Section 3:** Geospatial, finally
# ##### The names are all standardized/ normalized, now we can get to the geospatial
# ##### Through trial and error I've learned that we need to buffer the geometries, to overcome minor issues
# ##### And that buffering in 4326 avoids an issue with the geometry/boundary of Fiji, which has a landmass that crosses the 180/0 latitude

# %%
# Import a few packages
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import os
pd.options.display.max_rows = 300

# %%
print(os.getcwd())
os.chdir('G:/My Drive/Clark')
print(os.getcwd())
# Out:
# G:\My Drive\Clark\GIS Tutorials\Geog-312\Geog-312\1.Geopandas
# G:\My Drive\Clark

# %%
# And bring in the edited country boundary shapefile
# These are very detaile and precise polygons. Takes a few moments to load
countries_w_off_path = "GIS Tutorials/Geog-312/geopandas_Files/checkpoint2/countries_w_off_names.shp"
countries_w_off_names = gpd.read_file(countries_w_off_path)
print(len(countries_w_off_names))
countries_w_off_names.head(10)
# Out:
# 248
#                  COUNTRY   ISO           COUNTRYAFF  Population  \
# 0            Afghanistan    AF          Afghanistan    34262840
# 1  Akrotiri and Dhekelia  None       United Kingdom       18195
# 2                Albania    AL              Albania     2402113
# 3                Algeria    DZ              Algeria    46700000
# 4         American Samoa    AS        United States       49710
# 5                Andorra    AD              Andorra       86398
# 6                 Angola    AO               Angola    35121734
# 7               Anguilla    AI       United Kingdom       15780
# 8             Antarctica    AQ                 None           0
# 9    Antigua and Barbuda    AG  Antigua and Barbuda      103603
#
#                                 formalName  \
# 0           Islamic Emirate of Afghanistan
# 1                                     None
# 2                      Republic of Albania
# 3  People's Democratic Republic of Algeria
# 4                                     None
# 5                  Principality of Andorra
# 6                       Republic of Angola
# 7                                     None
# 8                                     None
# 9                      Antigua and Barbuda
#
#                                             geometry
# 0  POLYGON ((74.88986 37.23409, 74.88962 37.23314...
# 1  MULTIPOLYGON (((32.8388 34.70555, 32.84127 34....
# 2  MULTIPOLYGON (((20.0789 42.5558, 20.07939 42.5...
# 3  MULTIPOLYGON (((8.64188 36.94206, 8.64196 36.9...
# 4  MULTIPOLYGON (((-171.07753 -11.06622, -171.080...
# 5  POLYGON ((1.7258 42.5044, 1.71149 42.49224, 1....
# 6  MULTIPOLYGON (((13.10288 -4.68421, 13.10173 -4...
# 7  MULTIPOLYGON (((-63.42216 18.59739, -63.42672 ...
# 8  MULTIPOLYGON (((-46.15775 -60.51078, -46.1787 ...
# 9  MULTIPOLYGON (((-61.84592 17.72958, -61.83383 ...

# %%
# Verify CRS and buffer. Takes a few moments to run
print(countries_w_off_names.crs)
countries_buffed = countries_w_off_names
countries_buffed['geometry'] = countries_buffed['geometry'].buffer(0)
# Out:
# EPSG:4326

# %%
# # Plot county borders
# # They are very detailed boundary polygons and this takes a littlewhile to render/plot
# # REMEMBER to clear output of this and all folium map cells after inspecting
# # Leaving them open in a jupyter cell uses a lot of memory
# # Other option is to save an HTML of the folium map and inspect in browser window

# import folium
# m = folium.Map(location=[0,0], zoom_start=2)

# # Add only the polygon geometry as GeoJSON (avoiding LineStrings or other non-polygon geometries)
# folium.GeoJson(
#     countries_w_off_names[['geometry']],  # Use only the polygons from 'geometry' column
#     style_function=lambda x: {'fillOpacity': 0, 'color': 'blue'},
#     name="Country Boundaries"
# ).add_to(m)

# # OPTIONAL: Save the map
# # m.save('GIS Tutorials/GeoPy/1.Geopandas/activity_files/folium_maps/countries_boundary_check.html')

# # Or show the map
# m

# %% [markdown]
# ##### No need to run the two cells below
# ##### But if you do, the result of buffering in EPSG:6933 is the boundary of Fiji comes to include a few glitchy lines that run all the way around the equator!

# %%
# # Now, to compare, do the buffering in 6933
# buff6933 = countries_w_off_names.copy()
# buff6933 = buff6933.to_crs("EPSG:6933")
# buff6933['geometry'] = buff6933['geometry'].buffer(0)

# %%
# # # Plot county borders with glitchy Fiji geometry
# import folium
# m = folium.Map(location=[0,0], zoom_start=2)

# # Add only the polygon geometry as GeoJSON (avoiding LineStrings or other non-polygon geometries)
# folium.GeoJson(
#     buff6933[['geometry']],  # Use only the polygons from 'geometry' column
#     style_function=lambda x: {'fillOpacity': 0, 'color': 'blue'},
#     name="Country Boundaries"
# ).add_to(m)

# # Save weird map
# m.save('GIS Tutorials/GeoPy/1.Geopandas/activity_files/folium_maps/fiji_glitch.html')

# # Show the map
# m

# %%
# # Or, faster, create/save map with JUST glitchy vs good fiji, to compare

# # Initialize a Folium map
# m = folium.Map(location=[-17.7134, 178.0650], zoom_start=5)  # Centering near Fiji's approximate location

# # Filter the GeoDataFrame to include only Fiji's boundary
# fiji_good = countries_w_off_names[countries_w_off_names['COUNTRY'] == 'Fiji']

# # Add Fiji's boundary to the map as GeoJSON
# folium.GeoJson(
#     fiji_good[['geometry']],  # Only Fiji's geometry
#     style_function=lambda x: {'fillOpacity': 0, 'color': 'red', 'weight': 2},
#     name="Good Fiji"
# ).add_to(m)

# # Filter the GeoDataFrame to include only Fiji's boundary
# glitchyFiji = buff6933[buff6933['COUNTRY'] == 'Fiji']

# # Add Fiji's boundary to the map as GeoJSON
# folium.GeoJson(
#     glitchyFiji[['geometry']],  # Only Fiji's geometry
#     style_function=lambda x: {'fillOpacity': 0, 'color': 'blue', 'weight': 2},
#     name="Glitch Fiji"
# ).add_to(m)

# # Add a LayerControl to toggle layers on and off
# folium.LayerControl().add_to(m)

# # # Save the map
# # m.save('GIS Tutorials/GeoPy/1.Geopandas/activity_files/folium_maps/fji_boundary_compare.html')

# # Display the map if running in an interactive notebook
# m

# %% [markdown]
# ##### Buffering is best done in 4326, but calculating centroids, which requires accurate area, should be done in our projected coordinate system, 6933

# %%
print(countries_buffed.crs)
# Reproject to a global equal-area projection
# This is necessary when doing any kind of distance calculation, such as determining centroids
countries6933 = countries_buffed.to_crs("EPSG:6933")
print(countries6933.crs)
# Centroids should be calculated in the projected CRS
countries6933['centroid'] = countries6933.geometry.centroid
# Out:
# EPSG:4326
# EPSG:6933

# %%
# Verify that centroids and geometry are both in meters
countries6933.head()
# Out:
#                  COUNTRY   ISO      COUNTRYAFF  Population  \
# 0            Afghanistan    AF     Afghanistan    34262840
# 1  Akrotiri and Dhekelia  None  United Kingdom       18195
# 2                Albania    AL         Albania     2402113
# 3                Algeria    DZ         Algeria    46700000
# 4         American Samoa    AS   United States       49710
#
#                                 formalName  \
# 0           Islamic Emirate of Afghanistan
# 1                                     None
# 2                      Republic of Albania
# 3  People's Democratic Republic of Algeria
# 4                                     None
#
#                                             geometry  \
# 0  POLYGON ((7225844.213 4429969.158, 7225820.477...
# 1  MULTIPOLYGON (((3271001.456 4208757.218, 32710...
# 2  MULTIPOLYGON (((1937337.89 4953531.35, 1937385...
# 3  MULTIPOLYGON (((833823.241 4400105.218, 833831...
# 4  MULTIPOLYGON (((-16226341.969 -1837186.443, -1...
#
#                             centroid
# 0    POINT (6366923.369 4067003.428)
# 1    POINT (3218981.275 4180831.548)
# 2    POINT (1936226.181 4816925.087)
# 3     POINT (258594.776 3423503.594)
# 4  POINT (-16440866.53 -1795748.572)

# %%
# But for science, what happens if we calculate in 4326?
# Notice the warning
countries_buffed['centroid'] = countries_buffed.geometry.centroid
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_26516\2017718633.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   countries_buffed['centroid'] = countries_buffed.geometry.centroid

# %%
def reproject_geom_and_centroid(gdf, target_crs):
    """
    Reprojects the given GeoDataFrame to the target CRS, calculates the centroid coordinates
    in the target CRS, and adds the centroid coordinates as new columns to the reprojected GDF.

    Parameters:
    gdf (GeoDataFrame): The input GeoDataFrame with geometries to reproject.
    target_crs (str or int): The target CRS, either as an EPSG code or a PROJ string.

    Returns:
    GeoDataFrame: The reprojected GeoDataFrame with centroid coordinates as new columns.
    """
    # Reproject the GeoDataFrame to the target CRS
    gdf_reproj = gdf
    gdf_reproj = gdf_reproj.to_crs(epsg=target_crs)
    gdf_reproj['centroid'] = gdf_reproj['centroid'].to_crs(epsg=target_crs)

    # Return the reprojected GeoDataFrame with centroid coordinates
    return gdf_reproj

# %%
countries6933_reproj = reproject_geom_and_centroid(countries6933, '4326')
print("Check that countries4326 geometry and centroid are both in lat/lon coords:")
print(countries6933_reproj.crs)
countries6933_reproj.head()
# Out:
# Check that countries4326 geometry and centroid are both in lat/lon coords:
# EPSG:4326
#                  COUNTRY   ISO      COUNTRYAFF  Population  \
# 0            Afghanistan    AF     Afghanistan    34262840
# 1  Akrotiri and Dhekelia  None  United Kingdom       18195
# 2                Albania    AL         Albania     2402113
# 3                Algeria    DZ         Algeria    46700000
# 4         American Samoa    AS   United States       49710
#
#                                 formalName  \
# 0           Islamic Emirate of Afghanistan
# 1                                     None
# 2                      Republic of Albania
# 3  People's Democratic Republic of Algeria
# 4                                     None
#
#                                             geometry  \
# 0  POLYGON ((74.88986 37.23409, 74.88962 37.23314...
# 1  MULTIPOLYGON (((33.90121 35.09612, 33.90185 35...
# 2  MULTIPOLYGON (((20.0789 42.5558, 20.07939 42.5...
# 3  MULTIPOLYGON (((8.64188 36.94206, 8.64196 36.9...
# 4  MULTIPOLYGON (((-168.17253 -14.55294, -168.173...
#
#                       centroid
# 0    POINT (65.98786 33.75477)
# 1    POINT (33.36206 34.83019)
# 2    POINT (20.06737 41.12698)
# 3     POINT (2.68012 27.89881)
# 4  POINT (-170.3959 -14.21789)

# %%
# # But there is still an issue with the centroid of Fiji!
# # Plot centroids in each projection, and the country boundary of Fiji
# # Interesting to note how the difference in 4326 and 6933 centroid calculation is greater when further from the equator
# # Create the map
# m = folium.Map(location=[0, 0], zoom_start=2)

# # Filter the GeoDataFrame to include only Fiji's boundary
# fiji_boundary = countries_buffed[countries_buffed['COUNTRY'] == 'Fiji']

# # Add only Fiji's boundary to the map as a layer
# fiji_boundary_layer = folium.FeatureGroup(name="Fiji Boundary")
# folium.GeoJson(
#     fiji_boundary[['geometry']],  # Use only Fiji's geometry
#     style_function=lambda x: {'fillOpacity': 0, 'color': 'blue', 'weight': 2}
# ).add_to(fiji_boundary_layer)
# fiji_boundary_layer.add_to(m)

# # Add the centroids as calculated in the geographic CRS (4326) as circle markers, with Fiji in a different color
# centroids_4326_layer = folium.FeatureGroup(name="Centroids 4326")
# for _, row in countries_buffed.iterrows():
#     centroid_color = 'yellow' if row['COUNTRY'] == 'Fiji' else 'blue'  # Fiji in yellow, others in blue
#     folium.CircleMarker(
#         location=[row['centroid'].y, row['centroid'].x],
#         radius=3,
#         color=centroid_color,
#         fill=True,
#         fill_color=centroid_color,
#         fill_opacity=1 
#     ).add_child(folium.Tooltip(f"Geographic CRS (4326) centroid: {row['COUNTRY']}")).add_to(centroids_4326_layer)
# centroids_4326_layer.add_to(m)

# # Add the centroids as calculated the projected CRS (6933) as circle markers, with Fiji in a different color
# centroids_6933_layer = folium.FeatureGroup(name="Centroids 6933")
# for _, row in countries6933_reproj.iterrows():
#     centroid_color = 'red' if row['COUNTRY'] == 'Fiji' else 'green'  # Fiji in red, others in green
#     folium.CircleMarker(
#         location=[row['centroid'].y, row['centroid'].x],
#         radius=3,
#         color=centroid_color,
#         fill=True,
#         fill_color=centroid_color,
#         fill_opacity=1 
#     ).add_child(folium.Tooltip(f"Projected CRS (6933) centroid: {row['COUNTRY']}")).add_to(centroids_6933_layer)
# centroids_6933_layer.add_to(m)

# # Add a LayerControl to toggle layers on and off
# folium.LayerControl().add_to(m)

# # Save map
# m.save('GIS Tutorials/GeoPy/1.Geopandas/activity_files/folium_maps/centroidComparison.html')

# # Show the map
# m

# %%
# So, we need to calculate the centroid of Fiji using a more Fiji-specific CRS
# Pull out Fiji boundary from unmodified gdf (no centroids)
fiji_gdf = countries_w_off_names[countries_w_off_names['COUNTRY'] == 'Fiji']
# We will use EPSG:3832 (South Pacific 1958 / Fiji 1958)
fiji_gdf_3832 = fiji_gdf.to_crs(epsg=3832)

# Calculate the centroid of Fiji in the projected CRS
fiji_gdf_3832['centroid'] = fiji_gdf_3832.geometry.centroid

fiji_centroid_3832 = fiji_gdf_3832.geometry.centroid.iloc[0]

# Display the centroid coordinates. Will be in meters
print(f"Fiji centroid in EPSG:3832: {fiji_centroid_3832}")
# Out:
# Fiji centroid in EPSG:3832: POINT (3176924.386078355 -1960148.7447583182)

# %%
# # Now project this point gdf to 4326 to check our work
# fiji_reproj_4326 = reproject_and_get_centroid(fiji_gdf_3832, 4326)

# fiji_centroid4326 = fiji_reproj_4326.geometry.centroid.iloc[0]
# # Look what happens if you 
# print(f"Reprojected to 4326: {fiji_centroid4326}")

# %%
# Now project this point gdf to 4326 to check our work
fiji_reproj_4326 = reproject_geom_and_centroid(fiji_gdf_3832, 4326)
fiji_reproj_4326
# Out:
#    COUNTRY ISO COUNTRYAFF  Population        formalName  \
# 72    Fiji  FJ       Fiji      893468  Republic of Fiji
#
#                                              geometry  \
# 72  MULTIPOLYGON (((179.99667 -16.53378, 179.98753...
#
#                       centroid
# 72  POINT (178.5388 -17.44728)

# %%
# Visualize to check new Fiji centroid is correct
m = folium.Map(location=[0, 0], zoom_start=2)

# Filter the GeoDataFrame to include only Fiji's boundary
fiji_boundary = countries_buffed[countries_buffed['COUNTRY'] == 'Fiji']

# Add only Fiji's boundary to the map as a layer
fiji_boundary_layer = folium.FeatureGroup(name="Fiji Boundary")
folium.GeoJson(
    fiji_boundary[['geometry']],  # Use only Fiji's geometry
    style_function=lambda x: {'fillOpacity': 0, 'color': 'blue', 'weight': 2}
).add_to(fiji_boundary_layer)
fiji_boundary_layer.add_to(m)

# Add the centroids as circle markers for the geographic CRS (4326), with Fiji in a different color
centroids_4326_layer = folium.FeatureGroup(name="Centroids 4326")
for _, row in countries_buffed.iterrows():
    centroid_color = 'yellow' if row['COUNTRY'] == 'Fiji' else 'blue'  # Fiji in yellow, others in blue
    folium.CircleMarker(
        location=[row['centroid'].y, row['centroid'].x],
        radius=3,
        color=centroid_color,
        fill=True,
        fill_color=centroid_color,
        fill_opacity=1 
    ).add_child(folium.Tooltip(f"Geographic CRS (4326) centroid: {row['COUNTRY']}")).add_to(centroids_4326_layer)
centroids_4326_layer.add_to(m)

# Add the centroids as circle markers for the projected CRS (6933), with Fiji in a different color
centroids_6933_layer = folium.FeatureGroup(name="Centroids 6933")
for _, row in countries6933_reproj.iterrows():
    centroid_color = 'red' if row['COUNTRY'] == 'Fiji' else 'green'  # Fiji in red, others in green
    folium.CircleMarker(
        location=[row['centroid'].y, row['centroid'].x],
        radius=3,
        color=centroid_color,
        fill=True,
        fill_color=centroid_color,
        fill_opacity=1 
    ).add_child(folium.Tooltip(f"Projected CRS (6933) centroid: {row['COUNTRY']}")).add_to(centroids_6933_layer)
centroids_6933_layer.add_to(m)

# Reproject Fiji's centroid from EPSG:3832 to EPSG:4326 and plot it
fiji_centroid_4326 = fiji_reproj_4326['centroid'].iloc[0]  # Extract the centroid after reprojection
centroid_color = 'pink'  # Fiji centroid in pink
folium.CircleMarker(
    location=[fiji_centroid_4326.y, fiji_centroid_4326.x],  # Use the reprojected centroid
    radius=5,
    color=centroid_color,
    fill=True,
    fill_color=centroid_color,
    fill_opacity=1 
).add_child(folium.Tooltip(f"Fiji Centroid calculated in EPSG:3832")).add_to(m)

# Add a LayerControl to toggle layers on and off
folium.LayerControl().add_to(m)

# # Save
# m.save('GIS Tutorials/GeoPy/1.Geopandas/activity_files/folium_maps/centroidComparison.html')

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91422d76f4a70a03361066d4154a3eee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91422d76f4a70a03361066d4154a3eee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91422d76f4a70a03361066d4154a3eee = L.map(
#                 &quot;map_91422d76f4a70a03361066d4154a3eee&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b82f3572ab127d9d0ec0554391cd326 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0b82f3572ab127d9d0ec0554391cd326.addTo(map_91422d76f4a70a03361066d4154a3eee);
#
#
#             var feature_group_333e8acabf2399d18c5e52e6c31ed570 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_955bb65c1c7c9f13b3e3e44e9e54adaa_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_955bb65c1c7c9f13b3e3e44e9e54adaa_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_955bb65c1c7c9f13b3e3e44e9e54adaa = L.geoJson(null, {
#                 onEachFeature: geo_json_955bb65c1c7c9f13b3e3e44e9e54adaa_onEachFeature,
#
#                 style: geo_json_955bb65c1c7c9f13b3e3e44e9e54adaa_styler,
#         });
#
#         function geo_json_955bb65c1c7c9f13b3e3e44e9e54adaa_add (data) {
#             geo_json_955bb65c1c7c9f13b3e3e44e9e54adaa
#                 .addData(data);
#         }
#             geo_json_955bb65c1c7c9f13b3e3e44e9e54adaa_add({&quot;bbox&quot;: [-179.99999999990004, -21.738658950550075, 180.00000000010004, -12.457111359601527], &quot;features&quot;: [{&quot;bbox&quot;: [-179.99999999990004, -21.738658950550075, 180.00000000010004, -12.457111359601527], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[179.9966736003065, -16.53377724032731], [179.9875335601257, -16.54211043035201], [179.98669440002664, -16.54211043035201], [179.9858397598971, -16.540416720055532], [179.9841614396987, -16.54044534008034], [179.98338312053465, -16.539583230181904], [179.9808350399053, -16.5396384899243], [179.97795108047808, -16.53669360052919], [179.97795108047808, -16.534166310426826], [179.98042284014207, -16.530860880125488], [179.98043832017242, -16.52666661027581], [179.98381043970005, -16.524166140654813], [179.98377984026752, -16.521694200227103], [179.98208604003878, -16.520000489930624], [179.9821166403707, -16.514194500076087], [179.98291007983642, -16.512527430396574], [179.9841614396987, -16.51211163064721], [179.98710624006105, -16.508333250479097], [179.98710624006105, -16.50752829069802], [179.98916615969063, -16.505443529994864], [179.99172972035035, -16.50461193049614], [179.992080720349, -16.503334019949023], [179.99377451967837, -16.50086019004567], [179.99374392024583, -16.49919510067332], [179.9954222404441, -16.49749950000188], [179.99543772047446, -16.495832430322366], [180.00000000010004, -16.490444220524296], [180.00000000010004, -16.532138790672605], [179.99749764010403, -16.53377724032731], [179.9966736003065, -16.53377724032731]]], [[[179.9941712403106, -16.146278370650236], [179.9966736003065, -16.14794346002259], [180.00000000010004, -16.147916820304943], [180.00000000010004, -16.17124941063173], [179.9966736003065, -16.172082900505416], [179.9963074800063, -16.174222920051648], [179.99499528010813, -16.175443680481408], [179.98663320026208, -16.17958260065643], [179.9850005997979, -16.180444710554923], [179.98167420000436, -16.180444710554923], [179.97918696031002, -16.18208316020963], [179.9783629205125, -16.181249580403744], [179.9741973597204, -16.18455501070514], [179.9733124798871, -16.184583630729946], [179.97250356039103, -16.18544385025342], [179.97085584052468, -16.184610360379793], [179.96664420026968, -16.186277430059306], [179.96458427974073, -16.1883602104553], [179.96377571997357, -16.190834040358652], [179.96002200011526, -16.1929721704293], [179.95458996005868, -16.194972960533676], [179.95628339965924, -16.19583318005715], [179.9562988796896, -16.197555510378436], [179.95707719975303, -16.198333740509668], [179.95582583989062, -16.199611650157465], [179.95169051970174, -16.199611650157465], [179.9512480802348, -16.20255474000919], [179.9487457202389, -16.20583344066074], [179.94836411990832, -16.207111350308537], [179.94589236024433, -16.20708273028373], [179.9441985600156, -16.209583290736248], [179.94329820015184, -16.209583290736248], [179.94250475978686, -16.207944840182165], [179.94044484015728, -16.209167490087566], [179.94004812042454, -16.210443510259722], [179.93583683989834, -16.210443510259722], [179.93499767979915, -16.21125027048356], [179.932525

# %%
# It worked! 
# Now lets replace the centroid coordinates in countries6933
# Project fiji_gdf_3832 to 6933
fiji_6933= reproject_geom_and_centroid(fiji_gdf_3832, 6933)

fiji_6933
# Out:
#    COUNTRY ISO COUNTRYAFF  Population        formalName  \
# 72    Fiji  FJ       Fiji      893468  Republic of Fiji
#
#                                              geometry  \
# 72  MULTIPOLYGON (((17367209.493 -2080868.346, 173...
#
#                              centroid
# 72  POINT (17226544.434 -2192446.141)

# %%
# Check that countries 6933 is still in meters for both centroid and geometry
countries6933.head()
# Out:
#                  COUNTRY   ISO      COUNTRYAFF  Population  \
# 0            Afghanistan    AF     Afghanistan    34262840
# 1  Akrotiri and Dhekelia  None  United Kingdom       18195
# 2                Albania    AL         Albania     2402113
# 3                Algeria    DZ         Algeria    46700000
# 4         American Samoa    AS   United States       49710
#
#                                 formalName  \
# 0           Islamic Emirate of Afghanistan
# 1                                     None
# 2                      Republic of Albania
# 3  People's Democratic Republic of Algeria
# 4                                     None
#
#                                             geometry  \
# 0  POLYGON ((7225844.213 4429969.158, 7225820.477...
# 1  MULTIPOLYGON (((3271001.456 4208757.218, 32710...
# 2  MULTIPOLYGON (((1937337.89 4953531.35, 1937385...
# 3  MULTIPOLYGON (((833823.241 4400105.218, 833831...
# 4  MULTIPOLYGON (((-16226341.969 -1837186.443, -1...
#
#                             centroid
# 0    POINT (6366923.369 4067003.428)
# 1    POINT (3218981.275 4180831.548)
# 2    POINT (1936226.181 4816925.087)
# 3     POINT (258594.776 3423503.594)
# 4  POINT (-16440866.53 -1795748.572)

# %%
# Check how wrong the centroid calculation was in this
# Obviously going to be an issue issue with a single piece of land spanning longitude 180/0
countries6933[countries6933['COUNTRY'] == 'Fiji']
# Out:
#    COUNTRY ISO COUNTRYAFF  Population        formalName  \
# 72    Fiji  FJ       Fiji      893468  Republic of Fiji
#
#                                              geometry  \
# 72  MULTIPOLYGON (((17367209.493 -2080868.346, 173...
#
#                            centroid
# 72  POINT (279729.909 -2127208.895)

# %%
# Pull out the corrected Fiji centroid value
fiji_centroid_6933 = fiji_6933['centroid'].iloc[0]

# Replace the centroid value in countries6933 where 'COUNTRY' is 'Fiji'
countries6933.loc[countries6933['COUNTRY'] == 'Fiji', 'centroid'] = fiji_centroid_6933

# Verify the change
countries6933[countries6933['COUNTRY'] == 'Fiji']
# Out:
#    COUNTRY ISO COUNTRYAFF  Population        formalName  \
# 72    Fiji  FJ       Fiji      893468  Republic of Fiji
#
#                                              geometry  \
# 72  MULTIPOLYGON (((17367209.493 -2080868.346, 173...
#
#                              centroid
# 72  POINT (17226544.434 -2192446.141)

# %%
# Should be correct centroid coords now
countries6933[countries6933['COUNTRY'] == 'Fiji']
# Out:
#    COUNTRY ISO COUNTRYAFF  Population        formalName  \
# 72    Fiji  FJ       Fiji      893468  Republic of Fiji
#
#                                              geometry  \
# 72  MULTIPOLYGON (((17367209.493 -2080868.346, 173...
#
#                              centroid
# 72  POINT (17226544.434 -2192446.141)

# %%
# # Lets make sure we added the geometry correctly, and everything is straightened out
# # Reproject back to 4326
# countries_reproj= reproject_geom_and_centroid(countries6933, 4326)

# # And visualize
# m = folium.Map(location=[0, 0], zoom_start=2)

# # Filter the GeoDataFrame to include only Fiji's boundary
# fiji_boundary = countries_buffed[countries_buffed['COUNTRY'] == 'Fiji']

# # Add only Fiji's boundary to the map as a layer
# fiji_boundary_layer = folium.FeatureGroup(name="Fiji Boundary")
# folium.GeoJson(
#     fiji_boundary[['geometry']],  # Use only Fiji's geometry
#     style_function=lambda x: {'fillOpacity': 0, 'color': 'blue', 'weight': 2}
# ).add_to(fiji_boundary_layer)
# fiji_boundary_layer.add_to(m)

# # Add the centroids as circle markers for the geographic CRS (4326), with Fiji in a different color
# centroids_4326_layer = folium.FeatureGroup(name="Centroids 4326")
# for _, row in countries_buffed.iterrows():
#     centroid_color = 'yellow' if row['COUNTRY'] == 'Fiji' else 'blue'  # Fiji in yellow, others in blue
#     folium.CircleMarker(
#         location=[row['centroid'].y, row['centroid'].x],
#         radius=3,
#         color=centroid_color,
#         fill=True,
#         fill_color=centroid_color,
#         fill_opacity=1 
#     ).add_child(folium.Tooltip(f"Geographic CRS (4326) centroid: {row['COUNTRY']}")).add_to(centroids_4326_layer)
# centroids_4326_layer.add_to(m)

# # Add the centroids as circle markers for the projected CRS (6933), with Fiji in a different color
# centroids_6933_layer = folium.FeatureGroup(name="Centroids 6933")
# for _, row in countries_reproj.iterrows():
#     centroid_color = 'red' if row['COUNTRY'] == 'Fiji' else 'green'  # Fiji in red, others in green
#     folium.CircleMarker(
#         location=[row['centroid'].y, row['centroid'].x],
#         radius=3,
#         color=centroid_color,
#         fill=True,
#         fill_color=centroid_color,
#         fill_opacity=1 
#     ).add_child(folium.Tooltip(f"Projected CRS (6933) centroid: {row['COUNTRY']}")).add_to(centroids_6933_layer)
# centroids_6933_layer.add_to(m)

# # Add a LayerControl to toggle layers on and off
# folium.LayerControl().add_to(m)

# # Show the map
# m

# %% [markdown]
# ##### After all that, the geometry of fjii is still screwy enough that the centroidOut calculations don't work
# ##### So here's the deal, Jack
# ##### We have to run **shapely.make_valid** on the geometries of all the polygons in countries 6933 to calculate the centroids.
# ##### Fiji's still has to be set manually.
# ##### Also, running **make_valid** on the glitchy fiji polygon turns the geometry into a **"GEOMETRYCOLLECTION (MULTIPOLYGON"**
# ##### So, we will re-replace fiji's geometry from fiji_6933

# %%
# # Create field indicating if centroid is in or out of country boundary
# countries_reproj['centroidOut'] = countries_reproj.apply(lambda row: 0 if row['geometry'].contains(row['centroid']) else 1, axis=1)

# print("Check new field, and that countries6933 geometry and centroid are both in meters:")
# # print(countries6933.crs)
# print(countries_reproj.head())

# %%
from shapely.validation import make_valid
countries6933_1 = countries6933.copy()
# Create field indicating if centroid is in or out of country boundary
# Apply the centroid containment check only for countries other than Fiji
countries6933_1['geometry'] = countries6933_1['geometry'].apply(lambda geom: make_valid(geom))

countries6933_1['centroidOut'] = countries6933_1.apply(
    lambda row: 0 if row['geometry'].contains(row['centroid']) else 1
    if row['COUNTRY'] != 'Fiji' else None,  # Set Fiji to None temporarily
    axis=1
)

# Set Fiji's 'centroidOut' value manually to 1 (indicating the centroid is out)
countries6933_1.loc[countries6933_1['COUNTRY'] == 'Fiji', 'centroidOut'] = 1

# %%
# Should be correct centroid coords now
countries6933_1[countries6933_1['COUNTRY'] == 'Fiji']
# Out:
#    COUNTRY ISO COUNTRYAFF  Population        formalName  \
# 72    Fiji  FJ       Fiji      893468  Republic of Fiji
#
#                                              geometry  \
# 72  GEOMETRYCOLLECTION (MULTIPOLYGON (((-17353464....
#
#                              centroid  centroidOut
# 72  POINT (17226544.434 -2192446.141)          1.0

# %%
# Reproject to 4326
countries_4326_1 = reproject_geom_and_centroid(countries6933_1, 4326)
countries_4326_1
# Out:
#                                           COUNTRY   ISO  \
# 0                                     Afghanistan    AF
# 1                           Akrotiri and Dhekelia  None
# 2                                         Albania    AL
# 3                                         Algeria    DZ
# 4                                  American Samoa    AS
# 5                                         Andorra    AD
# 6                                          Angola    AO
# 7                                        Anguilla    AI
# 8                                      Antarctica    AQ
# 9                             Antigua and Barbuda    AG
# 10                                      Argentina    AR
# 11                                        Armenia    AM
# 12                                          Aruba    AW
# 13                                      Australia    AU
# 14                                        Austria    AT
# 15                                     Azerbaijan    AZ
# 16                                        Bahamas    BS
# 17                                        Bahrain    BH
# 18                                     Bangladesh    BD
# 19                                       Barbados    BB
# 20                                        Belarus    BY
# 21                                        Belgium    BE
# 22                                         Belize    BZ
# 23                                          Benin    BJ
# 24                                        Bermuda    BM
# 25                                         Bhutan    BT
# 26                                        Bolivia    BO
# 27                         Bosnia and Herzegovina    BA
# 28                                       Botswana    BW
# 29                                  Bouvet Island    BV
# 30                                         Brazil    BR
# 31                 British Indian Ocean Territory    IO
# 32                         British Virgin Islands    VG
# 33                                         Brunei    BN
# 34                                       Bulgaria    BG
# 35                                   Burkina Faso    BF
# 36                                        Burundi    BI
# 37                                       Cambodia    KH
# 38                                       Cameroon    CM
# 39                                         Canada    CA
# 40                                     Cape Verde    CV
# 41                          Caribbean Netherlands  None
# 42                                 Cayman Islands    KY
# 43                       Central African Republic    CF
# 44                                           Chad    TD
# 45                                          Chile    CL
# 46                                          China    CN
# 47                               Christmas Island    CX
# 48                                  Cocos Islands    CC
# 49                                       Colombia    CO
# 50                                        Comoros    KM
# 51                                   Cook Islands    CK
# 52                                     Costa Rica    CR
# 53                                        Croatia    HR
# 54                                           Cuba    CU
# 55                                         Cyprus    CY
# 56                                        Czechia    CZ
# 57               Democratic Republic of the Congo    CD
# 58                                        Denmark    DK
# 59                                       Djibouti    DJ
# 60                                       Dominica    DM
# 61                             Dominican Republic    DO
# 62                                        Ecuador    EC
# 63                                          Egypt    EG
# 64                                    El Salvador    SV
# 65                              Equatorial Guinea    GQ
# 66                                        Eritrea    ER
# 67                                        Estonia    EE
# 68                                       Eswatini    SZ
# 69                                       Ethiopia    ET
# 70                               Falkland Islands    FK
# 71                                  Faroe Islands    FO
# 72                                           Fiji    FJ
# 73                                        Finland    FI
# 74                                         France    FR
# 75                                  French Guiana    GF
# 76                               French Polynesia    PF
# 77            French Southern and Antarctic Lands    TF
# 78                                          Gabon    GA
# 79                                     The Gambia    GM
# 80                                        Georgia    GE
# 81                                        Germany    DE
# 82                                          Ghana    GH
# 83                                      Gibraltar    GI
# 84                                         Greece    GR
# 85                                      Greenland    GL
# 86                                        Grenada    GD
# 87                                     Guadeloupe    GP
# 88                                           Guam    GU
# 89                                      Guatemala    GT
# 90                                       Guernsey    GG
# 91                                         Guinea    GN
# 92                                  Guinea-Bissau    GW
# 93                                         Guyana    GY
# 94                                          Haiti    HT
# 95              Heard Island and McDonald Islands    HM
# 96                                       Honduras    HN
# 97                                      Hong Kong  None
# 98                                        Hungary    HU
# 99                                        Iceland    IS
# 100                                         India    IN
# 101                                     Indonesia    ID
# 102                                          Iran    IR
# 103                                          Iraq    IQ
# 104                                       Ireland    IE
# 105                                   Isle of Man    IM
# 106                                        Israel    IL
# 107                                         Italy    IT
# 108                                   Ivory Coast    CI
# 109                                       Jamaica    JM
# 110                                         Japan    JP
# 111                                        Jersey    JE
# 112                                        Jordan    JO
# 113                                    Kazakhstan    KZ
# 114                                         Kenya    KE
# 115                                      Kiribati    KI
# 116                                        Kosovo  None
# 117                                        Kuwait    KW
# 118                                    Kyrgyzstan    KG
# 119                                          Laos    LA
# 120                                        Latvia    LV
# 121                                       Lebanon    LB
# 122                                       Lesotho    LS
# 123                                       Liberia    LR
# 124                                         Libya    LY
# 125                                 Liechtenstein    LI
# 126                                     Lithuania    LT
# 127                                    Luxembourg    LU
# 128                                         Macau  None
# 129                               North Macedonia    MK
# 130                                    Madagascar    MG
# 131                                        Malawi    MW
# 132                                      Malaysia    MY
# 133                                      Maldives    MV
# 134                                          Mali    ML
# 135                                         Malta    MT
# 136                              Marshall Islands    MH
# 137                                    Martinique    MQ
# 138                                    Mauritania    MR
# 139                                     Mauritius    MU
# 140                                       Mayotte    YT
# 141                                        Mexico    MX
# 142                                    Micronesia    FM
# 143                                       Moldova    MD
# 144                                        Monaco    MC
# 145                                      Mongolia    MN
# 146                                    Montenegro    ME
# 147                                    Montserrat    MS
# 148                                       Morocco    MA
# 149                                    Mozambique    MZ
# 150                                       Myanmar    MM
# 151                                       Namibia    NA
# 152                                         Nauru    NR
# 153                                         Nepal    NP
# 154                                   Netherlands    NL
# 155                                       Curacao    CW
# 156                                 New Caledonia    NC
# 157                                   New Zealand    NZ
# 158                                     Nicaragua    NI
# 159                                         Niger    NE
# 160                                       Nigeria    NG
# 161                                          Niue    NU
# 162                                Norfolk Island    NF
# 163                                   North Korea    KP
# 164                      Northern Mariana Islands  None
# 165                                        Norway    NO
# 166                                          Oman    OM
# 167                                      Pakistan    PK
# 168                                         Palau    PW
# 169                                     Palestine    PS
# 170                                        Panama    PA
# 171                              Papua New Guinea    PG
# 172                                      Paraguay    PY
# 173                                          Peru    PE
# 174                                   Philippines    PH
# 175                              Pitcairn Islands    PN
# 176                                        Poland    PL
# 177                                      Portugal    PT
# 178                                   Puerto Rico    PR
# 179                                         Qatar    QA
# 180                         Republic of the Congo    CG
# 181                                       Reunion  None
# 182                                       Romania    RO
# 183                                        Russia    RU
# 184                                        Rwanda    RW
# 185                              Saint Barthelemy    BL
# 186  Saint Helena, Ascension and Tristan da Cunha    SH
# 187                         Saint Kitts and Nevis    KN
# 188                                   Saint Lucia    LC
# 189                                  Saint Martin    MF
# 190                     Saint Pierre and Miquelon    PM
# 191              Saint Vincent and the Grenadines    VC
# 192                                         Samoa    WS
# 193                                    San Marino    SM
# 194                         Sao Tome and Principe    ST
# 195                                  Saudi Arabia    SA
# 196                                       Senegal    SN
# 197                                        Serbia    RS
# 198                                    Seychelles    SC
# 199                                  Sierra Leone    SL
# 200                                     Singapore    SG
# 201                                      Slovakia    SK
# 202                                      Slovenia    SI
# 203                               Solomon Islands    SB
# 204                                       Somalia    SO
# 205                                  South Africa    ZA
# 206  South Georgia and the South Sandwich Islands  None
# 207                                   South Korea    KR
# 208                                   South Sudan    SS
# 209                                         Spain    ES
# 210                                     Sri Lanka    LK
# 211                                         Sudan    SD
# 212                                      Suriname    SR
# 213                        Svalbard and Jan Mayen    SJ
# 214                                        Sweden    SE
# 215                                   Switzerland    CH
# 216                                         Syria    SY
# 217                                        Taiwan  None
# 218                                    Tajikistan    TJ
# 219                                      Tanzania    TZ
# 220                                      Thailand    TH
# 221                                   Timor Leste    TL
# 222                                          Togo    TG
# 223                                       Tokelau    TK
# 224                                         Tonga    TO
# 225                           Trinidad and Tobago    TT
# 226                                       Tunisia    TN
# 227                                        Turkey    TR
# 228                                  Turkmenistan    TM
# 229                      Turks and Caicos Islands    TC
# 230                                        Tuvalu    TV
# 231                                        Uganda    UG
# 232                                       Ukraine    UA
# 233                          United Arab Emirates    AE
# 234                                United Kingdom    GB
# 235                                 United States    US
# 236                                       Uruguay    UY
# 237                             US Virgin Islands    VI
# 238                                    Uzbekistan    UZ
# 239                                       Vanuatu    VU
# 240                                  Vatican City    VA
# 241                                     Venezuela    VE
# 242                                       Vietnam    VN
# 243                             Wallis and Futuna    WF
# 244                                Western Sahara  None
# 245                                         Yemen    YE
# 246                                        Zambia    ZM
# 247                                      Zimbabwe    ZW
#
#                            COUNTRYAFF  Population  \
# 0                         Afghanistan    34262840
# 1                      United Kingdom       18195
# 2                             Albania     2402113
# 3                             Algeria    46700000
# 4                       United States       49710
# 5                             Andorra       86398
# 6                              Angola    35121734
# 7                      United Kingdom       15780
# 8                                None           0
# 9                 Antigua and Barbuda      103603
# 10                          Argentina    47067441
# 11                            Armenia     3039700
# 12                        Netherlands      107151
# 13                          Australia    27122411
# 14                            Austria     9179693
# 15                         Azerbaijan    10200013
# 16                            Bahamas      397360
# 17                            Bahrain     1588670
# 18                         Bangladesh   169828911
# 19                           Barbados      267800
# 20                            Belarus     9155978
# 21                            Belgium    11839987
# 22                             Belize      410919
# 23                              Benin    12910087
# 24                     United Kingdom       64055
# 25                             Bhutan      777224
# 26                            Bolivia    12006031
# 27             Bosnia and Herzegovina     3264873
# 28                           Botswana     2410338
# 29                             Norway           0
# 30                             Brazil   203080756
# 31                     United Kingdom           0
# 32                     United Kingdom       31538
# 33                             Brunei      445400
# 34                           Bulgaria     6445481
# 35                       Burkina Faso    23409015
# 36                            Burundi    12837740
# 37                           Cambodia    17336307
# 38                           Cameroon    28758503
# 39                             Canada    41288599
# 40                         Cape Verde      491233
# 41                        Netherlands           0
# 42                     United Kingdom       71105
# 43           Central African Republic     6470307
# 44                               Chad    18675547
# 45                              Chile    20086377
# 46                              China  1409670000
# 47                          Australia        1692
# 48                          Australia         593
# 49                           Colombia    52695952
# 50                            Comoros      900141
# 51                        New Zealand       15040
# 52                         Costa Rica     5309625
# 53                            Croatia     3859686
# 54                               Cuba    11089511
# 55                             Cyprus      918100
# 56                            Czechia    10879069
# 57   Democratic Republic of the Congo   105247000
# 58                            Denmark     5982117
# 59                           Djibouti     1001454
# 60                           Dominica       67408
# 61                 Dominican Republic    10760028
# 62                            Ecuador    16938986
# 63                              Egypt   105914499
# 64                        El Salvador     6351000
# 65                  Equatorial Guinea     1558160
# 66                            Eritrea     3748902
# 67                            Estonia     1374687
# 68                           Eswatini     1235549
# 69                           Ethiopia   109499000
# 70                     United Kingdom        3662
# 71                            Denmark       54908
# 72                               Fiji      893468
# 73                            Finland     5628931
# 74                             France    66265363
# 75                             France      295385
# 76                             France      279890
# 77                             France           0
# 78                              Gabon     2408586
# 79                         The Gambia     2417471
# 80                            Georgia     3694600
# 81                            Germany    84708010
# 82                              Ghana    33007618
# 83                     United Kingdom       34003
# 84                             Greece    10413982
# 85                            Denmark       56865
# 86                            Grenada      112579
# 87                             France      395726
# 88                      United States      153836
# 89                          Guatemala    17843132
# 90                     United Kingdom       64769
# 91                             Guinea    13261638
# 92                      Guinea-Bissau     1781308
# 93                             Guyana      772975
# 94                              Haiti    11743017
# 95                          Australia           0
# 96                           Honduras     9892632
# 97                              China     7531800
# 98                            Hungary     9584627
# 99                            Iceland      386970
# 100                             India  1404910000
# 101                         Indonesia   282477584
# 102                              Iran    85000000
# 103                              Iraq    44414800
# 104                           Ireland     5380300
# 105                    United Kingdom       84530
# 106                            Israel     9990300
# 107                             Italy    58974433
# 108                       Ivory Coast    29389150
# 109                           Jamaica     2825544
# 110                             Japan   123790000
# 111                    United Kingdom      103267
# 112                            Jordan    11516000
# 113                        Kazakhstan    20201849
# 114                             Kenya    52428290
# 115                          Kiribati      120740
# 116                            Kosovo     1762220
# 117                            Kuwait     4913271
# 118                        Kyrgyzstan     7100000
# 119                              Laos     7443000
# 120                            Latvia     1859800
# 121                           Lebanon     5490000
# 122                           Lesotho     2306000
# 123                           Liberia     5248621
# 124                             Libya     7381023
# 125                     Liechtenstein       40023
# 126                         Lithuania     2893887
# 127                        Luxembourg      672020
# 128                             China      687000
# 129                   North Macedonia     1826247
# 130                        Madagascar    30811969
# 131                            Malawi    20270568
# 132                          Malaysia    33980600
# 133                          Maldives      515132
# 134                              Mali    22395489
# 135                             Malta      542051
# 136                  Marshall Islands       42418
# 137                            France      349925
# 138                        Mauritania     4927532
# 139                         Mauritius     1259509
# 140                            France      320901
# 141                            Mexico   129940228
# 142                        Micronesia      105754
# 143                           Moldova     2423300
# 144                            Monaco       38367
# 145                          Mongolia     3504741
# 146                        Montenegro      616695
# 147                    United Kingdom        4386
# 148                           Morocco    37369652
# 149                        Mozambique    32419747
# 150                           Myanmar    56712559
# 151                           Namibia     3022401
# 152                             Nauru       11680
# 153                             Nepal    29164578
# 154                       Netherlands    18005142
# 155                       Netherlands      155826
# 156                            France      268510
# 157                       New Zealand     5338500
# 158                         Nicaragua     6803886
# 159                             Niger    26312034
# 160                           Nigeria   223800000
# 161                       New Zealand        1681
# 162                         Australia        2188
# 163                       North Korea    25950000
# 164                     United States       47329
# 165                            Norway     5571634
# 166                              Oman     5219940
# 167                          Pakistan   241499431
# 168                             Palau       16733
# 169                         Palestine     5483450
# 170                            Panama     4064780
# 171                  Papua New Guinea    11781559
# 172                          Paraguay     6109644
# 173                              Peru    34038457
# 174                       Philippines   114163719
# 175                    United Kingdom          35
# 176                            Poland    37552000
# 177                          Portugal    10639726
# 178                     United States     3205691
# 179                             Qatar     2857822
# 180             Republic of the Congo     6142180
# 181                            France      885700
# 182                           Romania    19064409
# 183                            Russia   146150789
# 184                            Rwanda    13798561
# 185                            France       10967
# 186                    United Kingdom        5651
# 187             Saint Kitts and Nevis       51320
# 188                       Saint Lucia      184100
# 189                            France       32358
# 190                            France        6092
# 191  Saint Vincent and the Grenadines      110872
# 192                             Samoa      205557
# 193                        San Marino       33984
# 194             Sao Tome and Principe      228319
# 195                      Saudi Arabia    32175224
# 196                           Senegal    18126390
# 197                            Serbia     6605168
# 198                        Seychelles      121355
# 199                      Sierra Leone     8494260
# 200                         Singapore     6036900
# 201                          Slovakia     5422194
# 202                          Slovenia     2124709
# 203                   Solomon Islands      750325
# 204                           Somalia    18143379
# 205                      South Africa    63015904
# 206                    United Kingdom           0
# 207                       South Korea    51248233
# 208                       South Sudan    14746494
# 209                             Spain    48797875
# 210                         Sri Lanka    21916000
# 211                             Sudan    50448963
# 212                          Suriname      616500
# 213                            Norway        2600
# 214                            Sweden    10576145
# 215                       Switzerland     9002763
# 216                             Syria    24672760
# 217                            Taiwan    23406608
# 218                        Tajikistan    10277100
# 219                          Tanzania    61741120
# 220                          Thailand    65969270
# 221                       Timor Leste     1373024
# 222                              Togo     8095498
# 223                       New Zealand        1647
# 224                             Tonga      100179
# 225               Trinidad and Tobago     1367510
# 226                           Tunisia    11850232
# 227                            Turkey    85372377
# 228                      Turkmenistan     7057841
# 229                    United Kingdom       49309
# 230                            Tuvalu       10679
# 231                            Uganda    45935046
# 232                           Ukraine    36700000
# 233              United Arab Emirates    10288946
# 234                    United Kingdom    68265209
# 235                     United States   335893238
# 236                           Uruguay     3444263
# 237                     United States       87146
# 238                        Uzbekistan    36963262
# 239                           Vanuatu      321409
# 240                      Vatican City         764
# 241                         Venezuela    28405543
# 242                           Vietnam   100300000
# 243                            France       11620
# 244                           Morocco      587259
# 245                             Yemen    32305264
# 246                            Zambia    19610769
# 247                          Zimbabwe    15178979
#
#                                             formalName  \
# 0                       Islamic Emirate of Afghanistan
# 1                                                 None
# 2                                  Republic of Albania
# 3              People's Democratic Republic of Algeria
# 4                                                 None
# 5                              Principality of Andorra
# 6                                   Republic of Angola
# 7                                                 None
# 8                                                 None
# 9                                  Antigua and Barbuda
# 10                                  Argentine Republic
# 11                                 Republic of Armenia
# 12                                                None
# 13                           Commonwealth of Australia
# 14                                 Republic of Austria
# 15                              Republic of Azerbaijan
# 16                         Commonwealth of The Bahamas
# 17                                  Kingdom of Bahrain
# 18                     People's Republic of Bangladesh
# 19                                            Barbados
# 20                                 Republic of Belarus
# 21                                  Kingdom of Belgium
# 22                                              Belize
# 23                                   Republic of Benin
# 24                                                None
# 25                                   Kingdom of Bhutan
# 26                      Plurinational State of Bolivia
# 27                              Bosnia and Herzegovina
# 28                                Republic of Botswana
# 29                                                None
# 30                       Federative Republic of Brazil
# 31                                                None
# 32                                                None
# 33                                   Brunei Darussalam
# 34                                Republic of Bulgaria
# 35                                        Burkina Faso
# 36                                 Republic of Burundi
# 37                                 Kingdom of Cambodia
# 38                                Republic of Cameroon
# 39                                              Canada
# 40                              Republic of Cabo Verde
# 41                                                None
# 42                                                None
# 43                            Central African Republic
# 44                                    Republic of Chad
# 45                                   Republic of Chile
# 46                          People's Republic of China
# 47                                                None
# 48                                                None
# 49                                Republic of Colombia
# 50                                Union of the Comoros
# 51                                                None
# 52                              Republic of Costa Rica
# 53                                 Republic of Croatia
# 54                                    Republic of Cuba
# 55                                  Republic of Cyprus
# 56                                      Czech Republic
# 57                   Congo, Democratic Republic of the
# 58                                  Kingdom of Denmark
# 59                                Republic of Djibouti
# 60                            Commonwealth of Dominica
# 61                                  Dominican Republic
# 62                                 Republic of Ecuador
# 63                              Arab Republic of Egypt
# 64                             Republic of El Salvador
# 65                       Republic of Equatorial Guinea
# 66                                    State of Eritrea
# 67                                 Republic of Estonia
# 68                                 Kingdom of Eswatini
# 69             Federal Democratic Republic of Ethiopia
# 70                                                None
# 71                                                None
# 72                                    Republic of Fiji
# 73                                 Republic of Finland
# 74                                     French Republic
# 75                                                None
# 76                                                None
# 77                                                None
# 78                                   Gabonese Republic
# 79                              Republic of The Gambia
# 80                                             Georgia
# 81                         Federal Republic of Germany
# 82                                   Republic of Ghana
# 83                                                None
# 84                                   Hellenic Republic
# 85                                                None
# 86                                             Grenada
# 87                                                None
# 88                                                None
# 89                               Republic of Guatemala
# 90                                                None
# 91                                  Republic of Guinea
# 92                           Republic of Guinea-Bissau
# 93                     Co-operative Republic of Guyana
# 94                                   Republic of Haiti
# 95                                                None
# 96                                Republic of Honduras
# 97   Hong Kong Special Administrative Region of the...
# 98                                             Hungary
# 99                                             Iceland
# 100                                  Republic of India
# 101                              Republic of Indonesia
# 102                           Islamic Republic of Iran
# 103                                   Republic of Iraq
# 104                                Republic of Ireland
# 105                                               None
# 106                                    State of Israel
# 107                                   Italian Republic
# 108                          Republic of Cote d'Ivoire
# 109                                            Jamaica
# 110                                              Japan
# 111                                               None
# 112                        Hashemite Kingdom of Jordan
# 113                             Republic of Kazakhstan
# 114                                  Republic of Kenya
# 115                               Republic of Kiribati
# 116                                 Republic of Kosovo
# 117                                    State of Kuwait
# 118                                    Kyrgyz Republic
# 119                   Lao People's Democratic Republic
# 120                                 Republic of Latvia
# 121                                Republic of Lebanon
# 122                                 Kingdom of Lesotho
# 123                                Republic of Liberia
# 124                                     State of Libya
# 125                      Principality of Liechtenstein
# 126                              Republic of Lithuania
# 127                          Grand Duchy of Luxembourg
# 128                                               None
# 129                        Republic of North Macedonia
# 130                             Republic of Madagascar
# 131                                 Republic of Malawi
# 132                                           Malaysia
# 133                               Republic of Maldives
# 134                                   Republic of Mali
# 135                                  Republic of Malta
# 136                   Republic of the Marshall Islands
# 137                                               None
# 138                     Islamic Republic of Mauritania
# 139                              Republic of Mauritius
# 140                                               None
# 141                              United Mexican States
# 142                     Federated States of Micronesia
# 143                                Republic of Moldova
# 144                             Principality of Monaco
# 145                                           Mongolia
# 146                                         Montenegro
# 147                                               None
# 148                                 Kingdom of Morocco
# 149                             Republic of Mozambique
# 150                   Republic of the Union of Myanmar
# 151                                Republic of Namibia
# 152                                  Republic of Nauru
# 153               Federal Democratic Republic of Nepal
# 154                         Kingdom of the Netherlands
# 155                                               None
# 156                                               None
# 157                                        New Zealand
# 158                              Republic of Nicaragua
# 159                              Republic of the Niger
# 160                        Federal Republic of Nigeria
# 161                                               None
# 162                                               None
# 163              Democratic People's Republic of Korea
# 164                                               None
# 165                                  Kingdom of Norway
# 166                                  Sultanate of Oman
# 167                       Islamic Republic of Pakistan
# 168                                  Republic of Palau
# 169                                 State of Palestine
# 170                                 Republic of Panama
# 171              Independent State of Papua New Guinea
# 172                               Republic of Paraguay
# 173                                   Republic of Peru
# 174                        Republic of the Philippines
# 175                                               None
# 176                                 Republic of Poland
# 177                                Portuguese Republic
# 178                                               None
# 179                                     State of Qatar
# 180                             Congo, Republic of the
# 181                                               None
# 182                                            Romania
# 183                                 Russian Federation
# 184                                 Republic of Rwanda
# 185                                               None
# 186                                               None
# 187          Federation of Saint Christopher and Nevis
# 188                                        Saint Lucia
# 189                                               None
# 190                                               None
# 191                   Saint Vincent and the Grenadines
# 192                         Independent State of Samoa
# 193                             Republic of San Marino
# 194                                               None
# 195                            Kingdom of Saudi Arabia
# 196                                Republic of Senegal
# 197                                 Republic of Serbia
# 198                             Republic of Seychelles
# 199                           Republic of Sierra Leone
# 200                              Republic of Singapore
# 201                                    Slovak Republic
# 202                               Republic of Slovenia
# 203                                    Solomon Islands
# 204                        Federal Republic of Somalia
# 205                           Republic of South Africa
# 206                                               None
# 207                                  Republic of Korea
# 208                            Republic of South Sudan
# 209                                   Kingdom of Spain
# 210         Democratic Socialist Republic of Sri Lanka
# 211                              Republic of the Sudan
# 212                               Republic of Suriname
# 213                                               None
# 214                                  Kingdom of Sweden
# 215                                Swiss Confederation
# 216                               Syrian Arab Republic
# 217                            Republic of China (ROC)
# 218                             Republic of Tajikistan
# 219                        United Republic of Tanzania
# 220                                Kingdom of Thailand
# 221                 Democratic Republic of Timor-Leste
# 222                                  Togolese Republic
# 223                                               None
# 224                                   Kingdom of Tonga
# 225                    Republic of Trinidad and Tobago
# 226                                Republic of Tunisia
# 227                                Republic of Turkiye
# 228                                       Turkmenistan
# 229                                               None
# 230                                             Tuvalu
# 231                                 Republic of Uganda
# 232                                            Ukraine
# 233                               United Arab Emirates
# 234  United Kingdom of Great Britain and Northern I...
# 235                           United States of America
# 236                       Oriental Republic of Uruguay
# 237                                               None
# 238                             Republic of Uzbekistan
# 239                                Republic of Vanuatu
# 240                                 Vatican City State
# 241                   Bolivarian Republic of Venezuela
# 242                      Socialist Republic of Vietnam
# 243                                               None
# 244                                               None
# 245                                  Republic of Yemen
# 246                                 Republic of Zambia
# 247                               Republic of Zimbabwe
#
#                                               geometry  \
# 0    POLYGON ((74.88986 37.23409, 74.88962 37.23314...
# 1    MULTIPOLYGON (((33.90121 35.09612, 33.90185 35...
# 2    MULTIPOLYGON (((20.0789 42.5558, 20.07939 42.5...
# 3    MULTIPOLYGON (((8.64188 36.94206, 8.64196 36.9...
# 4    MULTIPOLYGON (((-168.17253 -14.55294, -168.173...
# 5    POLYGON ((1.7258 42.5044, 1.71149 42.49224, 1....
# 6    MULTIPOLYGON (((23.99928 -10.89013, 23.99943 -...
# 7    MULTIPOLYGON (((-62.93497 18.30292, -62.93414 ...
# 8    MULTIPOLYGON (((-57.28856 -63.22003, -57.25061...
# 9    MULTIPOLYGON (((-61.66928 17.07375, -61.66839 ...
# 10   MULTIPOLYGON (((-71.78067 -44.22429, -71.78134...
# 11   MULTIPOLYGON (((45.01507 41.29709, 45.01577 41...
# 12   MULTIPOLYGON (((-70.04422 12.62403, -70.0442 1...
# 13   MULTIPOLYGON (((159.25336 -31.76631, 159.25162...
# 14   POLYGON ((16.9404 48.61674, 16.93997 48.61624,...
# 15   MULTIPOLYGON (((50.53828 40.34908, 50.55053 40...
# 16   MULTIPOLYGON (((-72.71297 22.32833, -72.71291 ...
# 17   MULTIPOLYGON (((50.82508 25.7387, 50.82261 25....
# 18   MULTIPOLYGON (((88.97783 26.44558, 88.97797 26...
# 19   POLYGON ((-59.60658 13.33244, -59.60244 13.328...
# 20   POLYGON ((28.15123 56.17074, 28.15142 56.16959...
# 21   MULTIPOLYGON (((4.8705 51.41293, 4.87087 51.41...
# 22   MULTIPOLYGON (((-87.48753 17.45458, -87.48544 ...
# 23   MULTIPOLYGON (((2.84087 12.40599, 2.84306 12.4...
# 24   MULTIPOLYGON (((-64.6682 32.37411, -64.65914 3...
# 25   POLYGON ((89.81913 28.24081, 89.82133 28.23905...
# 26   POLYGON ((-58.16851 -20.17224, -58.16925 -20.1...
# 27   MULTIPOLYGON (((19.0222 44.85549, 19.02346 44....
# 28   POLYGON ((25.26175 -17.79048, 25.26241 -17.791...
# 29   MULTIPOLYGON (((3.41075 -54.40417, 3.41331 -54...
# 30   MULTIPOLYGON (((-28.84149 -20.49399, -28.84149...
# 31   MULTIPOLYGON (((72.44417 -7.23714, 72.44958 -7...
# 32   MULTIPOLYGON (((-64.37583 18.74697, -64.37172 ...
# 33   MULTIPOLYGON (((115.15872 4.89239, 115.15938 4...
# 34   MULTIPOLYGON (((28.57835 43.73877, 28.57731 43...
# 35   POLYGON ((0.23006 14.9975, 0.23046 14.98362, 0...
# 36   POLYGON ((30.54271 -2.41268, 30.54244 -2.41409...
# 37   MULTIPOLYGON (((107.53816 14.68994, 107.53842 ...
# 38   MULTIPOLYGON (((15.49287 7.52779, 15.49283 7.5...
# 39   MULTIPOLYGON (((-55.89425 51.62414, -55.89167 ...
# 40   MULTIPOLYGON (((-22.66339 16.15619, -22.66214 ...
# 41   MULTIPOLYGON (((-62.99253 17.52125, -62.9917 1...
# 42   MULTIPOLYGON (((-79.73672 19.75789, -79.73503 ...
# 43   POLYGON ((22.87333 10.93677, 22.8729 10.9304, ...
# 44   POLYGON ((24 19.5, 24 19.45732, 24 19.41211, 2...
# 45   MULTIPOLYGON (((-66.53252 -55.18, -66.53 -55.1...
# 46   MULTIPOLYGON (((123.47414 53.4974, 123.47641 5...
# 47   POLYGON ((105.70453 -10.41506, 105.70453 -10.4...
# 48   MULTIPOLYGON (((96.92292 -12.19583, 96.92042 -...
# 49   MULTIPOLYGON (((-71.32378 11.84833, -71.33256 ...
# 50   MULTIPOLYGON (((44.48792 -12.115, 44.49164 -12...
# 51   MULTIPOLYGON (((-157.33333 -20.13294, -157.330...
# 52   MULTIPOLYGON (((-83.69759 10.93915, -83.69786 ...
# 53   MULTIPOLYGON (((16.37485 46.55246, 16.37651 46...
# 54   MULTIPOLYGON (((-81.14169 23.20622, -81.13917 ...
# 55   MULTIPOLYGON (((34.61703 35.70667, 34.61666 35...
# 56   POLYGON ((14.82337 50.87056, 14.82642 50.87189...
# 57   MULTIPOLYGON (((27.44591 5.018, 27.44634 5.017...
# 58   MULTIPOLYGON (((15.19581 55.3175, 15.19331 55....
# 59   MULTIPOLYGON (((43.44453 12.45075, 43.44161 12...
# 60   MULTIPOLYGON (((-61.43158 15.63792, -61.43119 ...
# 61   MULTIPOLYGON (((-71.75878 18.03193, -71.75874 ...
# 62   MULTIPOLYGON (((-80.04531 0.45744, -80.04569 0...
# 63   MULTIPOLYGON (((25.14163 31.66852, 25.1418 31....
# 64   MULTIPOLYGON (((-87.68158 13.16778, -87.68264 ...
# 65   MULTIPOLYGON (((9.83624 2.31317, 9.83619 2.313...
# 66   MULTIPOLYGON (((43.13705 12.7137, 43.13689 12....
# 67   MULTIPOLYGON (((28.0616 59.46253, 28.06536 59....
# 68   POLYGON ((31.97563 -25.95268, 31.97666 -25.954...
# 69   POLYGON ((42.40428 12.46864, 42.33944 12.39694...
# 70   MULTIPOLYGON (((-58.96566 -51.23412, -58.96167...
# 71   MULTIPOLYGON (((-6.3025 62.34581, -6.29503 62....
# 72   GEOMETRYCOLLECTION (MULTIPOLYGON (((-179.85422...
# 73   MULTIPOLYGON (((28.93002 69.05181, 28.92845 69...
# 74   MULTIPOLYGON (((9.55911 42.14128, 9.55828 42.1...
# 75   MULTIPOLYGON (((-51.62981 4.15339, -51.63206 4...
# 76   MULTIPOLYGON (((-134.83586 -23.11125, -134.835...
# 77   MULTIPOLYGON (((77.54511 -37.80956, 77.54839 -...
# 78   MULTIPOLYGON (((13.29705 2.17224, 13.29676 2.1...
# 79   MULTIPOLYGON (((-16.74792 13.06531, -16.74834 ...
# 80   MULTIPOLYGON (((46.42576 41.91234, 46.4254 41....
# 81   MULTIPOLYGON (((8.63574 54.91148, 8.64912 54.9...
# 82   MULTIPOLYGON (((-0.13623 11.13955, -0.13611 11...
# 83   POLYGON ((-5.33967 36.1532, -5.33967 36.1532, ...
# 84   MULTIPOLYGON (((29.63763 36.11178, 29.63184 36...
# 85   MULTIPOLYGON (((-33.93692 83.63339, -33.49117 ...
# 86   MULTIPOLYGON (((-61.37925 12.527, -61.38008 12...
# 87   MULTIPOLYGON (((-61.00467 16.35247, -61.00381 ...
# 88   MULTIPOLYGON (((144.86917 13.65125, 144.87497 ...
# 89   MULTIPOLYGON (((-89.15196 17.81388, -89.15196 ...
# 90   MULTIPOLYGON (((-2.15575 49.72709, -2.15744 49...
# 91   MULTIPOLYGON (((-11.37766 12.41376, -11.37702 ...
# 92   MULTIPOLYGON (((-13.70826 12.67458, -13.70954 ...
# 93   MULTIPOLYGON (((-57.14844 5.84314, -57.15109 5...
# 94   MULTIPOLYGON (((-71.75847 19.70292, -71.75843 ...
# 95   MULTIPOLYGON (((73.30075 -52.97333, 73.30325 -...
# ...
# 183  MULTIPOLYGON (((43.27947 66.09731, 43.28147 66...
# 184  POLYGON ((30.47322 -1.05767, 30.47232 -1.05779...
# 185  MULTIPOLYGON (((-62.86714 17.92333, -62.86666 ...
# 186  MULTIPOLYGON (((-5.63211 -15.98253, -5.63253 -...
# 187  MULTIPOLYGON (((-62.58328 17.20542, -62.5783 1...
# 188  MULTIPOLYGON (((-60.93242 14.10347, -60.93089 ...
# 189  MULTIPOLYGON (((-62.98583 18.11542, -62.98836 ...
# 190  MULTIPOLYGON (((-56.08717 46.8725, -56.09184 4...
# 191  MULTIPOLYGON (((-61.16836 13.38042, -61.16747 ...
# 192  MULTIPOLYGON (((-171.41042 -14.01586, -171.413...
# 193  POLYGON ((12.50939 43.99229, 12.50956 43.9913,...
# 194  MULTIPOLYGON (((7.47414 1.69206, 7.4725 1.6920...
# 195  MULTIPOLYGON (((44.89248 29.18574, 44.91679 29...
# 196  MULTIPOLYGON (((-12.23888 14.76416, -12.23761 ...
# 197  POLYGON ((20.26374 46.12619, 20.26311 46.1248,...
# 198  MULTIPOLYGON (((56.26039 -7.17669, 56.25834 -7...
# 199  MULTIPOLYGON (((-10.27934 8.4846, -10.27874 8....
# 200  MULTIPOLYGON (((104.40621 1.32976, 104.40541 1...
# 201  POLYGON ((22.56543 49.08783, 22.56552 49.08738...
# 202  POLYGON ((16.59671 46.47613, 16.59652 46.47493...
# 203  MULTIPOLYGON (((170.10042 -11.96083, 170.09836...
# 204  MULTIPOLYGON (((41.55918 -1.66196, 41.55891 -1...
# 205  MULTIPOLYGON (((37.93247 -46.61042, 37.93581 -...
# 206  MULTIPOLYGON (((-26.40667 -58.37625, -26.40167...
# 207  MULTIPOLYGON (((131.87037 37.24199, 131.87024 ...
# 208  POLYGON ((34.10667 9.5, 34.10683 9.49803, 34.1...
# 209  MULTIPOLYGON (((4.09539 40.08914, 4.09539 40.0...
# 210  MULTIPOLYGON (((80.21748 9.83206, 80.22083 9.8...
# 211  MULTIPOLYGON (((38.83839 18.61053, 38.83669 18...
# 212  POLYGON ((-54.00042 5.62765, -54.00079 5.62414...
# 213  MULTIPOLYGON (((33.3698 80.2412, 33.37986 80.2...
# 214  MULTIPOLYGON (((24.16741 65.70575, 24.1667 65....
# 215  POLYGON ((9.56134 47.50013, 9.56189 47.49894, ...
# 216  MULTIPOLYGON (((42.35248 37.09989, 42.35303 37...
# 217  MULTIPOLYGON (((122.10167 25.48375, 122.09914 ...
# 218  MULTIPOLYGON (((70.98775 40.22336, 70.98999 40...
# 219  MULTIPOLYGON (((33.93406 -1, 34.0125 -1, 34.01...
# 220  MULTIPOLYGON (((100.08464 20.35228, 100.08498 ...
# 221  MULTIPOLYGON (((127.33034 -8.41415, 127.3312 -...
# 222  POLYGON ((0.91667 11, 0.90241 10.95934, 0.8886...
# 223  MULTIPOLYGON (((-171.21089 -9.32625, -171.2042...
# 224  MULTIPOLYGON (((-173.70836 -15.86292, -173.711...
# 225  MULTIPOLYGON (((-60.50517 11.30578, -60.50433 ...
# 226  MULTIPOLYGON (((11.56244 33.16611, 11.56128 33...
# 227  MULTIPOLYGON (((41.54953 41.51995, 41.55204 41...
# 228  MULTIPOLYGON (((66.55373 37.35475, 66.55262 37...
# 229  MULTIPOLYGON (((-71.08389 21.34853, -71.08472 ...
# 230  MULTIPOLYGON (((179.90625 -9.42753, 179.90416 ...
# 231  POLYGON ((33.93406 -1, 33.89814 -1, 33.85299 -...
# 232  MULTIPOLYGON (((38.23077 47.12041, 38.22989 47...
# 233  MULTIPOLYGON (((56.26705 25.62794, 56.26714 25...
# 234  MULTIPOLYGON (((-3.33331 58.64872, -3.33167 58...
# 235  MULTIPOLYGON (((179.64497 52.02875, 179.64828 ...
# 236  MULTIPOLYGON (((-53.36938 -33.74424, -53.37523...
# 237  MULTIPOLYGON (((-64.76 17.78122, -64.75711 17....
# 238  MULTIPOLYGON (((70.94322 42.26363, 70.94461 42...
# 239  MULTIPOLYGON (((170.21042 -19.515, 170.21042 -...
# 240  POLYGON ((12.45547 41.90742, 12.4557 41.90631,...
# 241  MULTIPOLYGON (((-59.98153 8.5259, -59.87625 8....
# 242  MULTIPOLYGON (((109.47372 12.65081, 109.4725 1...
# 243  MULTIPOLYGON (((-176.12585 -13.28875, -176.129...
# 244  MULTIPOLYGON (((-8.66667 27.66877, -8.66667 27...
# 245  MULTIPOLYGON (((53.50997 12.70875, 53.51414 12...
# 246  POLYGON ((32.95964 -9.40068, 32.94946 -9.41173...
# 247  POLYGON ((30.42184 -15.62117, 30.42186 -15.624...
#
#                          centroid  centroidOut
# 0       POINT (65.98786 33.75477)          0.0
# 1       POINT (33.36206 34.83019)          1.0
# 2       POINT (20.06737 41.12698)          0.0
# 3        POINT (2.68012 27.89881)          0.0
# 4     POINT (-170.3959 -14.21789)          1.0
# 5         POINT (1.57627 42.5454)          0.0
# 6      POINT (17.54511 -12.24251)          0.0
# 7        POINT (-63.0639 18.2312)          0.0
# 8      POINT (27.94983 -75.41679)          0.0
# 9      POINT (-61.79912 17.27757)          1.0
# 10    POINT (-64.95061 -34.31238)          0.0
# 11      POINT (44.94315 40.28782)          0.0
# 12      POINT (-69.9705 12.51348)          0.0
# 13     POINT (134.38889 -25.2588)          0.0
# 14      POINT (14.13364 47.57699)          0.0
# 15      POINT (47.52521 40.27931)          0.0
# 16     POINT (-76.61311 24.23151)          1.0
# 17      POINT (50.56119 26.02514)          0.0
# 18       POINT (90.2731 23.82013)          0.0
# 19     POINT (-59.55749 13.17275)          0.0
# 20      POINT (28.04051 53.49611)          0.0
# 21       POINT (4.66465 50.63504)          0.0
# 22      POINT (-88.6908 17.20367)          0.0
# 23        POINT (2.33807 9.64315)          0.0
# 24     POINT (-64.76824 32.30869)          1.0
# 25      POINT (90.43219 27.39392)          0.0
# 26    POINT (-64.66846 -16.64574)          0.0
# 27      POINT (17.78895 44.15901)          0.0
# 28      POINT (23.81989 -22.1407)          0.0
# 29      POINT (3.40985 -54.43381)          0.0
# 30    POINT (-53.14533 -10.40718)          0.0
# 31      POINT (72.15185 -6.67208)          1.0
# 32     POINT (-64.51891 18.50357)          1.0
# 33      POINT (114.74923 4.52295)          0.0
# 34      POINT (25.23169 42.74603)          0.0
# 35        POINT (-1.7466 12.2684)          0.0
# 36      POINT (29.89181 -3.36509)          0.0
# 37     POINT (104.91607 12.70476)          0.0
# 38       POINT (12.73994 5.67565)          0.0
# 39     POINT (-97.71783 57.62253)          0.0
# 40     POINT (-23.98215 15.94315)          1.0
# 41     POINT (-67.37808 13.15701)          1.0
# 42     POINT (-80.87962 19.42418)          1.0
# 43       POINT (20.48156 6.56976)          0.0
# 44      POINT (18.66316 15.27121)          0.0
# 45    POINT (-71.23993 -35.57707)          0.0
# 46     POINT (103.56921 35.60214)          0.0
# 47     POINT (105.63636 -10.4854)          0.0
# 48     POINT (96.84159 -12.13494)          1.0
# 49      POINT (-73.07854 3.88674)          0.0
# 50     POINT (43.67893 -11.89125)          1.0
# 51   POINT (-159.13807 -18.92182)          1.0
# 52       POINT (-84.1965 9.96945)          0.0
# 53      POINT (16.39585 45.01427)          1.0
# 54     POINT (-79.01779 21.61661)          0.0
# 55      POINT (33.22377 35.05661)          0.0
# 56      POINT (15.33518 49.73026)          0.0
# 57      POINT (23.65207 -2.85145)          0.0
# 58      POINT (10.02303 55.96252)          0.0
# 59      POINT (42.58011 11.74229)          0.0
# 60     POINT (-61.35905 15.43198)          0.0
# 61     POINT (-70.49533 18.89225)          0.0
# 62     POINT (-78.77492 -1.42554)          0.0
# 63      POINT (29.88182 26.39993)          0.0
# 64     POINT (-88.86568 13.73359)          0.0
# 65       POINT (10.33228 1.70394)          0.0
# 66      POINT (38.84759 15.37258)          0.0
# 67        POINT (25.5422 58.6619)          0.0
# 68     POINT (31.49764 -26.56382)          0.0
# 69       POINT (39.63727 8.60389)          0.0
# 70    POINT (-59.38497 -51.74139)          1.0
# 71      POINT (-6.89136 62.06708)          0.0
# 72     POINT (178.5388 -17.44728)          1.0
# 73      POINT (26.16687 64.06882)          0.0
# 74       POINT (2.56455 46.43716)          0.0
# 75      POINT (-53.24241 3.90788)          0.0
# 76   POINT (-145.31402 -15.13638)          1.0
# 77     POINT (68.60178 -48.86756)          1.0
# 78      POINT (11.78848 -0.60497)          0.0
# 79     POINT (-15.38726 13.45297)          0.0
# 80      POINT (43.51345 42.17339)          0.0
# 81      POINT (10.38169 50.99809)          0.0
# 82       POINT (-1.20603 7.95512)          0.0
# 83       POINT (-5.34841 36.1342)          0.0
# 84      POINT (22.99448 38.97957)          0.0
# 85     POINT (-41.62677 72.00083)          0.0
# 86     POINT (-61.65979 12.15491)          0.0
# 87     POINT (-61.53471 16.20144)          1.0
# 88     POINT (144.77585 13.44184)          0.0
# 89      POINT (-90.3587 15.68889)          0.0
# 90       POINT (-2.5169 49.48452)          1.0
# 91     POINT (-10.92917 10.43321)          0.0
# 92     POINT (-14.97792 12.01217)          0.0
# 93      POINT (-58.97408 4.78256)          0.0
# 94     POINT (-72.68941 18.93377)          1.0
# 95     POINT (73.51013 -53.09405)          0.0
# 96       POINT (-86.617 14.81959)          0.0
# 97     POINT (114.13555 22.38104)          0.0
# 98      POINT (19.40451 47.15353)          0.0
# 99     POINT (-18.59101 64.96188)          0.0
# 100     POINT (79.61173 22.55021)          0.0
# 101    POINT (117.29372 -2.21963)          1.0
# 102      POINT (54.38426 32.3695)          0.0
# 103     POINT (43.78059 32.98231)          0.0
# 104     POINT (-8.15882 53.15222)          0.0
# 105     POINT (-4.53928 54.22526)          0.0
# 106     POINT (34.96544 31.34433)          0.0
# 107     POINT (12.14152 42.61645)          0.0
# 108      POINT (-5.55293 7.61422)          0.0
# 109    POINT (-77.31214 18.15709)          0.0
# 110    POINT (137.75783 37.23161)          1.0
# 111     POINT (-2.13071 49.20832)          0.0
# 112     POINT (36.78115 31.23318)          0.0
# 113     POINT (67.23258 47.88777)          0.0
# 114      POINT (37.84525 0.55706)          0.0
# 115     POINT (-43.66727 0.62878)          1.0
# 116     POINT (20.88936 42.57957)          0.0
# 117     POINT (47.61387 29.35192)          0.0
# 118     POINT (74.51357 41.44391)          0.0
# 119    POINT (103.78829 18.45897)          0.0
# 120     POINT (24.93058 56.84437)          0.0
# 121     POINT (35.89267 33.91866)          0.0
# 122     POINT (28.2474 -29.58022)          0.0
# 123       POINT (-9.3087 6.44498)          0.0
# 124      POINT (18.0567 26.92289)          0.0
# 125        POINT (9.553 47.14165)          0.0
# 126      POINT (23.9053 55.32304)          0.0
# 127       POINT (6.09284 49.7759)          0.0
# 128    POINT (113.55771 22.15822)          0.0
# 129     POINT (21.70001 41.59741)          0.0
# 130    POINT (46.71939 -19.28335)          0.0
# 131    POINT (34.30439 -13.20023)          0.0
# 132      POINT (109.72261 3.7909)          1.0
# 133      POINT (73.19952 3.68017)          1.0
# 134     POINT (-3.53912 17.25464)          0.0
# 135     POINT (14.39931 35.92379)          0.0
# 136     POINT (169.02273 8.49537)          1.0
# 137    POINT (-61.02314 14.64931)          0.0
# 138    POINT (-10.34865 20.16966)          0.0
# 139     POINT (57.8831 -20.11022)          1.0
# 140    POINT (45.14581 -12.81929)          0.0
# 141     POINT (-102.364 23.70583)          0.0
# 142     POINT (154.51122 7.15745)          1.0
# 143     POINT (28.47033 47.18744)          0.0
# 144       POINT (7.4232 43.73665)          0.0
# 145     POINT (103.10599 46.7005)          0.0
# 146     POINT (19.25155 42.78371)          0.0
# 147    POINT (-62.19325 16.73953)          0.0
# 148     POINT (-6.31898 31.78205)          0.0
# 149     POINT (35.58774 -17.1269)          0.0
# 150     POINT (96.50866 20.98908)          0.0
# 151    POINT (17.21513 -22.02916)          0.0
# 152    POINT (166.93001 -0.51969)          0.0
# 153     POINT (83.95827 28.24544)          0.0
# 154      POINT (5.60772 52.23615)          0.0
# 155    POINT (-68.96784 12.19633)          0.0
# 156   POINT (165.69101 -21.30381)          0.0
# 157      POINT (171.386 -41.5996)          1.0
# 158     POINT (-85.03921 12.8398)          0.0
# 159      POINT (9.37622 17.35016)          0.0
# 160        POINT (8.0971 9.56931)          0.0
# 161  POINT (-169.86219 -19.05199)          0.0
# 162   POINT (167.93851 -29.04268)          0.0
# 163    POINT (127.15686 40.11131)          0.0
# 164    POINT (145.60956 15.92719)          1.0
# 165     POINT (13.14483 63.59319)          1.0
# 166     POINT (56.09154 20.55679)          0.0
# 167     POINT (69.31077 29.80288)          0.0
# 168     POINT (134.49936 7.39577)          1.0
# 169     POINT (35.20465 31.90936)          0.0
# 170     POINT (-80.11227 8.51093)          0.0
# 171    POINT (145.25953 -6.46868)          0.0
# 172    POINT (-58.4162 -23.18682)          0.0
# 173     POINT (-74.3767 -9.08962)          0.0
# 174    POINT (122.87982 11.66079)          1.0
# 175   POINT (-128.4846 -24.43028)          1.0
# 176      POINT (19.41575 52.0621)          0.0
# 177      POINT (-8.5504 39.54619)          0.0
# 178    POINT (-66.46926 18.22006)          0.0
# 179     POINT (51.19106 25.28214)          0.0
# 180     POINT (15.22358 -0.83776)          0.0
# 181     POINT (55.53852 -21.1214)          0.0
# 182     POINT (24.97888 45.80859)          0.0
# 183     POINT (95.39127 59.58912)          0.0
# 184     POINT (29.92538 -2.00027)          0.0
# 185    POINT (-62.83646 17.90865)          0.0
# 186   POINT (-10.46893 -23.86397)          1.0
# 187    POINT (-62.70399 17.27021)          1.0
# 188     POINT (-60.9678 13.89632)          0.0
# 189    POINT (-63.06163 18.08024)          0.0
# 190    POINT (-56.31015 46.93189)          1.0
# 191    POINT (-61.20671 13.19214)          0.0
# 192  POINT (-172.19124 -13.74409)          1.0
# 193     POINT (12.46335 43.93837)          0.0
# 194        POINT (6.70053 0.4112)          1.0
# 195     POINT (44.60738 23.97151)          0.0
# 196    POINT (-14.46517 14.35428)          0.0
# 197     POINT (20.80305 44.20856)          0.0
# 198     POINT (51.83965 -6.70468)          1.0
# 199     POINT (-11.78965 8.55795)          0.0
# 200     POINT (103.81657 1.36076)          0.0
# 201     POINT (19.47972 48.70248)          0.0
# 202     POINT (14.81964 46.11638)          0.0
# 203    POINT (159.58928 -8.88509)          1.0
# 204      POINT (45.85645 6.02883)          1.0
# 205    POINT (25.14681 -28.87636)          0.0
# 206   POINT (-35.90012 -54.65659)          1.0
# 207    POINT (127.80147 36.33524)          0.0
# 208      POINT (30.20461 7.32098)          0.0
# 209     POINT (-3.67482 40.11001)          0.0
# 210      POINT (80.70069 7.61749)          0.0
# 211     POINT (29.97709 15.95685)          0.0
# 212     POINT (-55.90652 4.13754)          0.0
# 213     POINT (18.18155 78.69107)          0.0
# 214     POINT (16.51936 62.13452)          0.0
# 215      POINT (8.22782 46.79506)          0.0
# 216     POINT (38.48696 34.99246)          0.0
# 217    POINT (120.95068 23.74803)          0.0
# 218     POINT (71.01403 38.51221)          0.0
# 219     POINT (34.81491 -6.24336)          0.0
# 220    POINT (101.01067 15.03909)          0.0
# 221    POINT (125.85418 -8.82015)          0.0
# 222       POINT (0.97954 8.52488)          0.0
# 223    POINT (-171.7797 -9.06642)          1.0
# 224  POINT (-174.81593 -19.81671)          1.0
# 225    POINT (-61.26213 10.47166)          0.0
# 226       POINT (9.5797 34.06001)          0.0
# 227      POINT (35.17032 39.0183)          0.0
# 228     POINT (59.22184 39.13958)          0.0
# 229     POINT (-71.8197 21.75381)          0.0
# 230    POINT (178.19668 -7.64227)          1.0
# 231      POINT (32.39146 1.27712)          0.0
# 232     POINT (31.43729 48.93362)          0.0
# 233     POINT (54.32676 23.90404)          0.0
# 234     POINT (-2.84444 53.96672)          0.0
# 235   POINT (-107.53112 42.09866)          0.0
# 236   POINT (-56.02115 -32.77408)          0.0
# 237    POINT (-64.80218 17.97874)          1.0
# 238      POINT (63.2049 41.69696)          0.0
# 239   POINT (167.69835 -16.18795)          1.0
# 240      POINT (12.45296 41.9034)          0.0
# 241     POINT (-66.14495 7.11565)          0.0
# 242    POINT (106.32941 16.49389)          1.0
# 243  POINT (-177.20938 -13.82552)          1.0
# 244     POINT (-13.1613 24.61562)          0.0
# 245     POINT (47.58473 15.89077)          0.0
# 246    POINT (27.81404 -13.42223)          0.0
# 247     POINT (29.87188 -18.9773)          0.0

# %%
# Get the geometry from countries_buffed
# Remember we already ran this: fiji_boundary = countries_buffed[countries_buffed['COUNTRY'] == 'Fiji']
fiji_geo = fiji_boundary['geometry'].iloc[0]

# %%
# Get the geometry from fiji_6933
fiji_geo_6933 = fiji_6933['geometry'].iloc[0]

# Replace the geometry value in countries6933 where 'COUNTRY' is 'Fiji'
countries_4326_1.loc[countries_4326_1['COUNTRY'] == 'Fiji', 'geometry'] = fiji_geo

# %%
# Should be correct centroid coords now
countries_4326_1[countries_4326_1['COUNTRY'] == 'Fiji']
# Out:
#    COUNTRY ISO COUNTRYAFF  Population        formalName  \
# 72    Fiji  FJ       Fiji      893468  Republic of Fiji
#
#                                              geometry  \
# 72  MULTIPOLYGON (((179.99667 -16.53378, 179.98753...
#
#                       centroid  centroidOut
# 72  POINT (178.5388 -17.44728)          1.0

# %% [markdown]
# ### What a quagmire! As the wikipedia page for the island of Tavueni, Fiji says:
# ##### "An interesting note is that the island of Taveuni crosses the east–west antimeridian, so the "north-eastern" portion of the island is located at -179 degrees longitude and the south-western part at +179 degrees longitude. This is often an example that causes havoc to GIS software, in which a polygon geometry around the perimeter of the island is incorrectly rendered and wraps around the globe.

# %%
# # Does everything finally line up??
# # Again, this will take a couple minutes to run
# m = folium.Map(location=[0,0], zoom_start=2)

# # Add only the polygon geometry as GeoJSON (avoiding LineStrings or other non-polygon geometries)
# folium.GeoJson(
#     countries_4326_1[['geometry']],  # Use only the polygons from 'geometry' column
#     style_function=lambda x: {'fillOpacity': 0, 'color': 'blue'},
#     name="Country Boundaries"
# ).add_to(m)

# # Add only the polygon geometry as GeoJSON (avoiding LineStrings or other non-polygon geometries)
# folium.GeoJson(
#     countries_4326_1[['geometry']],  # Use only the polygons from 'geometry' column
#     style_function=lambda x: {'fillOpacity': 0, 'color': 'blue'},
#     name="Country Boundaries"
# ).add_to(m)

# # OPTIONAL: Save the map
# # m.save('GIS Tutorials/GeoPy/1.Geopandas/activity_files/folium_maps/countries_boundary_check.html')

# # Or show the map
# m

# %% [markdown]
# ##### Shapefiles can only have one geometry column. So we will split our gdf into two different single geometry gdfs to save as shapefiles.
# ##### For a version to easily upload back into python/geopandas we'll save it as a parquet

# %%
# Split into reproj_geom with main geometry and other attributes except centroid
reproj_geom = countries_4326_1.drop(columns='centroid')

# Split into reproj_centroids with centroid and any non-geometry columns (exclude main geometry)
reproj_centroids = countries_4326_1.drop(columns='geometry')
reproj_centroids = reproj_centroids.set_geometry('centroid')

# %%
# # Split into reproj_geom with main geometry and other attributes except centroid
# reproj_geom = countries6933_1.drop(columns='centroid')

# # Split into reproj_centroids with centroid and any non-geometry columns (exclude main geometry)
# reproj_centroids = countries6933_1.drop(columns='geometry')
# reproj_centroids = reproj_centroids.set_geometry('centroid')

# %%
reproj_centroids.to_file("GIS Tutorials/Geog-312/geopandas_Files/checkpoint2/countries_w_off_names.shp", driver='ESRI Shapefile')
reproj_geom.to_file("GIS Tutorials/Geog-312/geopandas_Files/checkpoint3/reproj_geom.shp", driver='ESRI Shapefile')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_26516\898618992.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   reproj_centroids.to_file("GIS Tutorials/Geog-312/Activity_Files/checkpoint2/countries_w_off_names.shp", driver='ESRI Shapefile')
# C:\Users\User\miniconda3\envs\geo\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'centroidOut' to 'centroidOu'
#   ogr_write(
# C:\Users\User\AppData\Local\Temp\ipykernel_26516\898618992.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   reproj_geom.to_file("GIS Tutorials/Geog-312/Activity_Files/checkpoint3/reproj_geom.shp", driver='ESRI Shapefile')
# C:\Users\User\miniconda3\envs\geo\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'centroidOut' to 'centroidOu'
#   ogr_write(

# %%
# Save as Parquet file
countries_4326_1.to_parquet("GIS Tutorials/Geog-312/geopandas_Files/checkpoint3/reproj.parquet")

# # Or, save as Feather file
# countries6933_1.to_feather("countries_with_centroids.feather")
